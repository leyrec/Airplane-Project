# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
import pprint

# %%
types_df = pd.read_csv("ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# Import API key
gkey="h323GWkBwCy3RkzoJGx19eR-THnde-e6YJ4sAkN-zvZOyPCB35nTwT5EPzgpxzZmnvTkd-bWEPqY8TPyiUlTgiSnRXZI8rj-rJ63QOeUZAvHy5MxB-rvFoRkJ5K9XXYx"

# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc, target_key, target_type):
    params = {
    "location": target_loc, 
    "term": target_key,
    "categories": target_type,    
}
    return params
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
loc = str(input("Where are you located?\n"))

name= []
city=[]
latitude= []
longitude= []
price= []
rating=[]
output=[]


def get_rest(cuisine,loc):
    
    #these are the additional params
    add_params = {"sort_by" : "review_count"}

    #these are the original params
    params = s_params(loc,cuisine,"restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    pprint.pprint(s1_results)
    
    if (s1_results):
        name = s1_results["businesses"][0]["name"]
        city = s1_results["businesses"][0]["location"]["city"]
        latitude = s1_results["businesses"][0]["coordinates"]["latitude"]
        longitude = s1_results["businesses"][0]["coordinates"]["longitude"]
        price = s1_results["businesses"][0]["price"]
        rating=s1_results["businesses"][0]["rating"]
        output = [name,city,latitude,longitude,price, rating] 
    else:
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
    
    #print(f"The closest {cuisine.upper()} restaurant is {name} which has a rating of {rating} and is located at: \n {address} \n")   
    
    return output

#this is a long loop so print wait before starting
print("wait... this might take a few minutes.")

# use iterrows to iterate through pandas dataframe
# optional: use tqdm for progress bar: tqdm(iterator,total)
# like this: for index, row in tqdm(types_df.iterrows(), total=types_df.shape[0]):

for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = str(row['ethnicity'])
   
    try:
        output = get_rest(restr_type, loc)
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])
        
        
    except (KeyError, IndexError):
        output = ["NaN","NaN","NaN","NaN","NaN","NaN","NaN"]
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])

#print done when done        
print("done!")
# Out:
# Where are you located?
# miami
# wait... this might take a few minutes.
# {'businesses': [{'alias': 'hakkasan-miami-beach',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 25.817791,
#                                  'longitude': -80.122166},
#                  'display_phone': '(786) 276-1388',
#                  'distance': 18118.27705891831,
#                  'id': 'mO_jC4t19hyDLV646Pj3kQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bB6X2zL1x9XC1r565_RsFA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4441 Collins Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami Beach',
#                               'country': 'US',
#                               'display_address': ['4441 Collins Ave',
#                                                   'Miami Beach, FL 33140'],
#                               'state': 'FL',
#                               'zip_code': '33140'},
#                  'name': 'Hakkasan',
#                  'phone': '+17862761388',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 772,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hakkasan-miami-beach?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'tropical-chinese-restaurant-miami-3',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 25.734035,
#                                  'longitude': -80.325937},
#                  'display_phone': '(305) 262-7576',
#                  'distance': 4324.907371756412,
#                  'id': 'b16cC-AVqP19dMguMgIs1w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ji2hMqIdWgYTnx5VCg6wXg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7991 SW 40th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['7991 SW 40th St',
#                                                   'Miami, FL 33155'],
#                               'state': 'FL',
#                               'zip_code': '33155'},
#                  'name': 'Tropical Chinese Restaurant',
#                  'phone': '+13052627576',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 712,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tropical-chinese-restaurant-miami-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'kon-chau-restaurant-miami',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 25.7324881946529,
#                                  'longitude': -80.3311729431153},
#                  'display_phone': '(305) 553-7799',
#                  'distance': 4868.46632057766,
#                  'id': 'PUN_di3c9KDaPY6kEa924w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DpiaAQc4vc_dcR-sp6Rykg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8376 SW 40th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['8376 SW 40th St',
#                                                   'Miami, FL 33155'],
#                               'state': 'FL',
#                               'zip_code': '33155'},
#                  'name': 'Kon Chau Restaurant',
#                  'phone': '+13055537799',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 655,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kon-chau-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': '107-taste-miami-3',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'ramen', 'title': 'Ramen'},
#                                 {'alias': 'panasian', 'title': 'Pan Asian'}],
#                  'coordinates': {'latitude': 25.7527, 'longitude': -80.367311},
#                  'display_phone': '(786) 717-6378',
#                  'distance': 7934.444772072226,
#                  'id': 'XXk0WJoXomMPlXsISgnXUQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7whZ_o0OK5v80jQWVEUAow/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1679 SW 107th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1679 SW 107th Ave',
#                                                   'Miami, FL 33165'],
#                               'state': 'FL',
#                               'zip_code': '33165'},
#                  'name': '107 Taste',
#                  'phone': '+17867176378',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 634,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/107-taste-miami-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'blackbrick-chinese-and-dim-sum-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.8094535860585,
#                                  'longitude': -80.1924000221596},
#                  'display_phone': '(305) 573-8886',
#                  'distance': 11469.077400404542,
#                  'id': 'Hpf4xBvE4CECwDUTTzkOQQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F9mzREWwaxZ8ynVV_z-LhQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3451 NE 1st Ave',
#                               'address2': 'Ste 103',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['3451 NE 1st Ave',
#                                                   'Ste 103',
#                                                   'Miami, FL 33137'],
#                               'state': 'FL',
#                               'zip_code': '33137'},
#                  'name': 'Blackbrick Chinese & Dim Sum',
#                  'phone': '+13055738886',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 499,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/blackbrick-chinese-and-dim-sum-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'chinese-guy-chi-town-restaurant-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.7677096022278,
#                                  'longitude': -80.3680984526397},
#                  'display_phone': '(786) 763-2008',
#                  'distance': 8183.555633224062,
#                  'id': 'QImSpb3QXtn7MJW4efFdoQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PMPq5yPzTi0Wwb7Ajy3dzA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '113 SW 107th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['113 SW 107th Ave',
#                                                   'Miami, FL 33174'],
#                               'state': 'FL',
#                               'zip_code': '33174'},
#                  'name': 'Chinese Guy Chi-town Restaurant',
#                  'phone': '+17867632008',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 340,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/chinese-guy-chi-town-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'red-shallot-doral',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#                  'coordinates': {'latitude': 25.79623, 'longitude': -80.34329},
#                  'display_phone': '(305) 477-2513',
#                  'distance': 7340.714538437271,
#                  'id': 'oWLJNm3IIWsHyX4okWwbZg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4-T2Fm53UThxAwV30iP8gg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9032 NW 25th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Doral',
#                               'country': 'US',
#                               'display_address': ['9032 NW 25th St',
#                                                   'Doral, FL 33172'],
#                               'state': 'FL',
#                               'zip_code': '33172'},
#                  'name': 'Red Shallot',
#                  'phone': '+13054772513',
#                  'price': '$',
#                  'rating': 5.0,
#                  'review_count': 244,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/red-shallot-doral?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'datangzhenwei-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'}],
#                  'coordinates': {'latitude': 25.7653321663146,
#                                  'longitude': -80.1889792449524},
#                  'display_phone': '(786) 747-4686',
#                  'distance': 10023.138890762748,
#                  'id': 'tNUg9mLG871y5lM1mMn6kw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JTwS4N6_4XPHFppvPn5Cvg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '801 Brickell Bay Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['801 Brickell Bay Dr',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'DaTangZhenWei',
#                  'phone': '+17867474686',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 198,
#                  'transactions': ['pickup', 'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/datangzhenwei-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'south-garden-chinese-restaurant-miami-2',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 25.7022204665748,
#                                  'longitude': -80.3692350027161},
#                  'display_phone': '(305) 274-9099',
#                  'distance': 9881.89815145396,
#                  'id': 'uq-M0-HWNytlAzfC6e3YDA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7FBIseDB015cJUeiccbbxg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '10855 SW 72nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['10855 SW 72nd St',
#                                                   'Miami, FL 33173'],
#                               'state': 'FL',
#                               'zip_code': '33173'},
#                  'name': 'South Garden Chinese Restaurant',
#                  'phone': '+13052749099',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 193,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/south-garden-chinese-restaurant-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'palmar-miami-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.8037205,
#                                  'longitude': -80.1987294},
#                  'display_phone': '(305) 542-0532',
#                  'distance': 10577.218558842604,
#                  'id': 'hgbWuZU90ws34jYLa3jDPw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WAEIq8ct0ANzKyh_AGTKzg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '180 NW 29th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['180 NW 29th St',
#                                                   'Miami, FL 33127'],
#                               'state': 'FL',
#                               'zip_code': '33127'},
#                  'name': 'Palmar',
#                  'phone': '+13055420532',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 160,
#                  'transactions': ['pickup',
#                                   'delivery',
#                                   'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/palmar-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pekin-chinese-restaurant-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.7490258,
#                                  'longitude': -80.2217551},
#                  'display_phone': '(305) 858-9801',
#                  'distance': 6656.8509349074,
#                  'id': 'Qb9hszxRtBeNHX-dttRiig',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/21yH0cJ5g-rVOzZyzu2V2Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2293 SW 17th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['2293 SW 17th Ave',
#                                                   'Miami, FL 33145'],
#                               'state': 'FL',
#                               'zip_code': '33145'},
#                  'name': 'Pekin Chinese Restaurant',
#                  'phone': '+13058589801',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 152,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/pekin-chinese-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'chef-chen-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.68769, 'longitude': -80.38041},
#                  'display_phone': '(305) 274-6799',
#                  'distance': 11762.41591902567,
#                  'id': 'Xj2cv0FaPgq74VcqVWx4ZQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_A2W3sfL3il2R0oCN8p2ZA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11557 N Kendall Dr',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['11557 N Kendall Dr',
#                                                   'Miami, FL 33176'],
#                               'state': 'FL',
#                               'zip_code': '33176'},
#                  'name': 'Chef Chen',
#                  'phone': '+13052746799',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 148,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/chef-chen-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'canton-palace-chinese-restaurant-miami',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'importedfood',
#                                  'title': 'Imported Food'}],
#                  'coordinates': {'latitude': 25.76146,
#                                  'longitude': -80.3259099},
#                  'display_phone': '(305) 264-9444',
#                  'distance': 3908.9928986222603,
#                  'id': 'jkYClGyThHsbBF5_avkf9w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kmhcLKmePG1hCnxTUlNkMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7980 SW 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['7980 SW 8th St',
#                                                   'Miami, FL 33144'],
#                               'state': 'FL',
#                               'zip_code': '33144'},
#                  'name': 'Canton Palace Chinese Restaurant',
#                  'phone': '+13052649444',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 146,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/canton-palace-chinese-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'silver-palace-miami-5',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.713165,
#                                  'longitude': -80.414234},
#                  'display_phone': '(305) 382-1598',
#                  'distance': 13380.749132173172,
#                  'id': 'LpgZHFLo2QXyD-yCrH2dTw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qm1ZeAhNiDWnfXuEnwkd3Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5771 SW 137th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['5771 SW 137th Ave',
#                                                   'Miami, FL 33183'],
#                               'state': 'FL',
#                               'zip_code': '33183'},
#                  'name': 'Silver Palace',
#                  'phone': '+13053821598',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 137,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/silver-palace-miami-5?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'china-casa-hialeah',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.8970682543049,
#                                  'longitude': -80.350708364418},
#                  'display_phone': '(305) 698-3881',
#                  'distance': 17227.68285902496,
#                  'id': 'qN3NWQ_oTbX8iryeeOjcyw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8uDU8RKcqPednAqNMR8HLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3300 W 84th St',
#                               'address2': 'Unit 5',
#                               'address3': None,
#                               'city': 'Hialeah',
#                               'country': 'US',
#                               'display_address': ['3300 W 84th St',
#                                                   'Unit 5',
#                                                   'Hialeah, FL 33018'],
#                               'state': 'FL',
#                               'zip_code': '33018'},
#                  'name': 'China Casa',
#                  'phone': '+13056983881',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 132,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/china-casa-hialeah?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'gourmet-gourmet-miami-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.77184, 'longitude': -80.26478},
#                  'display_phone': '(305) 443-8664',
#                  'distance': 3161.6474297509394,
#                  'id': 'hhVVQLQnCYCdi-_B-fVBWw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rc92Z9ApITyO1VctSyZESQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4249 W Flagler St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['4249 W Flagler St',
#                                                   'Miami, FL 33134'],
#                               'state': 'FL',
#                               'zip_code': '33134'},
#                  'name': 'Gourmet Gourmet',
#                  'phone': '+13054438664',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 126,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/gourmet-gourmet-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'restaurant-salon-canton-doral-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.79646,
#                                  'longitude': -80.3520999},
#                  'display_phone': '(305) 640-0666',
#                  'distance': 8044.287866432436,
#                  'id': 'N31v_-KjCj6yK8TIvBfMXQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_Bi58C2ZnHILPSCYbpNj0g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9668 NW 25th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Doral',
#                               'country': 'US',
#                               'display_address': ['9668 NW 25th St',
#                                                   'Doral, FL 33172'],
#                               'state': 'FL',
#                               'zip_code': '33172'},
#                  'name': 'Restaurant Salon Canton',
#                  'phone': '+13056400666',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 126,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/restaurant-salon-canton-doral-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'china-express-miami-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.77057, 'longitude': -80.28882},
#                  'display_phone': '(305) 639-8281',
#                  'distance': 1977.8628599247631,
#                  'id': 'byXml8ucI-z68JnV7aFpTg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r4tbyDYREkwIRU1PRh-B-Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5748 W Flagler St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['5748 W Flagler St',
#                                                   'Miami, FL 33144'],
#                               'state': 'FL',
#                               'zip_code': '33144'},
#                  'name': 'China Express',
#                  'phone': '+13056398281',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 123,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/china-express-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hokasan-miami',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 25.76364, 'longitude': -80.1936},
#                  'display_phone': '(305) 530-8922',
#                  'distance': 9532.515240814639,
#                  'id': 'JfAmB5IR3UTF0GVOoW2pVQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4eiRhKpx2ymsNQ71RI-gIw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '21 SW 11th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['21 SW 11th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Hokasan',
#                  'phone': '+13055308922',
#                  'rating': 3.5,
#                  'review_count': 104,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hokasan-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'canton-star-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.6975999419114,
#                                  'longitude': -80.4472771362457},
#                  'display_phone': '(305) 388-1828',
#                  'distance': 17085.42659804809,
#                  'id': 'IpS_5T4-h71KI7liybteVQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1gyG0ftJ7BlqCgGkHU2bEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '15718 SW 72nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['15718 SW 72nd St',
#                                                   'Miami, FL 33193'],
#                               'state': 'FL',
#                               'zip_code': '33193'},
#                  'name': 'Canton Star',
#                  'phone': '+13053881828',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 94,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/canton-star-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 25.752753731496888,
#                        'longitude': -80.2880859375}},
#  'total': 515}
# {'businesses': [{'alias': 'versailles-restaurant-miami',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'latin', 'title': 'Latin American'}],
#                  'coordinates': {'latitude': 25.7650962116388,
#                                  'longitude': -80.2527339189549},
#                  'display_phone': '(305) 444-0240',
#                  'distance': 3797.047096362616,
#                  'id': 'hZm7TunlrksQbgS0ssXbUg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TLEkE09ry4HsBMT2-vL-Zw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3555 SW 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['3555 SW 8th St',
#                                                   'Miami, FL 33135'],
#                               'state': 'FL',
#                               'zip_code': '33135'},
#                  'name': 'Versailles Restaurant',
#                  'phone': '+13054440240',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4482,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/versailles-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'puerto-sagua-restaurant-miami-beach',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 25.77713, 'longitude': -80.13275},
#                  'display_phone': '(305) 673-1115',
#                  'distance': 15796.565459193902,
#                  'id': 'SRRI61ud20RWX5mAJ-UiuQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UOhBnaFbGjL703WMIGxWfQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '700 Collins Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami Beach',
#                               'country': 'US',
#                               'display_address': ['700 Collins Ave',
#                                                   'Miami Beach, FL 33139'],
#                               'state': 'FL',
#                               'zip_code': '33139'},
#                  'name': 'Puerto Sagua Restaurant',
#                  'phone': '+13056731115',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3114,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/puerto-sagua-restaurant-miami-beach?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'havana-1957-miami-beach-9',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 25.7870366676539,
#                                  'longitude': -80.1319582600495},
#                  'display_phone': '(305) 503-3828',
#                  'distance': 16092.073548712166,
#                  'id': '0ojuKD3hhfNQvvFAOrVHCw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c2SuEXpthVznSv2gmdlcdg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '405 Espanola Way',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami Beach',
#                               'country': 'US',
#                               'display_address': ['405 Espanola Way',
#                                                   'Miami Beach, FL 33139'],
#                               'state': 'FL',
#                               'zip_code': '33139'},
#                  'name': 'Havana 1957',
#                  'phone': '+13055033828',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2517,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/havana-1957-miami-beach-9?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'finka-table-and-tap-miami',
#                  'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'cuban', 'title': 'Cuban'}],
#                  'coordinates': {'latitude': 25.7426710712095,
#                                  'longitude': -80.431843609787},
#                  'display_phone': '(305) 227-8818',
#                  'distance': 14441.61765013115,
#                  'id': 'QqdtuSDJQaEVZo9EkYhX5A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W-RQsXbVgLQBaQOHzcp1Zg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '14690 SW 26th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['14690 SW 26th St',
#                                                   'Miami, FL 33175'],
#                               'state': 'FL',
#                               'zip_code': '33175'},
#                  'name': 'FINKA Table & Tap',
#                  'phone': '+13052278818',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2343,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/finka-table-and-tap-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'havana-harrys-coral-gables',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'comfortfood',
#                                  'title': 'Comfort Food'}],
#                  'coordinates': {'latitude': 25.7291418497262,
#                                  'longitude': -80.262036540545},
#                  'display_phone': '(305) 661-2622',
#                  'distance': 3701.4687287084826,
#                  'id': 'T-4IayNd4xZ0VJ-AaIUPsw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AJq-sqPKJmz-BunhNIdWSA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4612 S Le Jeune Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Coral Gables',
#                               'country': 'US',
#                               'display_address': ['4612 S Le Jeune Rd',
#                                                   'Coral Gables, FL 33146'],
#                               'state': 'FL',
#                               'zip_code': '33146'},
#                  'name': "Havana Harry's",
#                  'phone': '+13056612622',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1207,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/havana-harrys-coral-gables?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'olds-havana-cuban-bar-and-cocina-miami',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 25.7655942148975,
#                                  'longitude': -80.2192383373502},
#                  'display_phone': '(786) 518-2196',
#                  'distance': 7041.043458941524,
#                  'id': 'UXHxLN3DcDGI57uDIfCuJA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LL9MYpbR_02BQUGOTzPC0Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1442 SW 8th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1442 SW 8th St',
#                                                   'Miami, FL 33135'],
#                               'state': 'FL',
#                               'zip_code': '33135'},
#                  'name': "Old's Havana Cuban Bar & Cocina",
#                  'phone': '+17865182196',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 844,
#                  'transactions': ['pickup', 'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/olds-havana-cuban-bar-and-cocina-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'little-havana-restaurant-north-miami',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'}],
#                  'coordinates': {'latitude': 25.89371, 'longitude': -80.16197},
#                  'display_phone': '(305) 899-9069',
#                  'distance': 20148.49177931848,
#                  'id': 'YIpSGYHzRkNwMTZ6uTrttA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HeOOPMmY4buslI4DZqmZuA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '12727 Biscayne Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'North Miami',
#                               'country': 'US',
#                               'display_address': ['12727 Biscayne Blvd',
#                                                   'North Miami, FL 33181'],
#                               'state': 'FL',
#                               'zip_code': '33181'},
#                  'name': 'Little Havana Restaurant',
#                  'phone': '+13058999069',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 705,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/little-havana-restaurant-north-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'la-carreta-miami-2',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 25.764745,
#                                  'longitude': -80.253938},
#                  'display_phone': '(305) 444-7501',
#                  'distance': 3670.512324037954,
#                  'id': 'mzfg6HomStmQWRGAsLw6Lg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YjEcTVkM_EExHePjoFKjVw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3632 SW 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['3632 SW 8th St',
#                                                   'Miami, FL 33135'],
#                               'state': 'FL',
#                               'zip_code': '33135'},
#                  'name': 'La Carreta',
#                  'phone': '+13054447501',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 652,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/la-carreta-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'tinta-y-café-miami-2',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'}],
#                  'coordinates': {'latitude': 25.7592231998562,
#                                  'longitude': -80.2586163778576},
#                  'display_phone': '(305) 285-0101',
#                  'distance': 3037.7219646757826,
#                  'id': '5Rq4O0gzalOQ79NenZUyqg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/036zR6QfbfRmsVVJ1jfCXw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1315 Ponce De Leon Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1315 Ponce De Leon Blvd',
#                                                   'Miami, FL 33134'],
#                               'state': 'FL',
#                               'zip_code': '33134'},
#                  'name': 'Tinta y Café',
#                  'phone': '+13052850101',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 628,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/tinta-y-caf%C3%A9-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'doce-provisions-miami',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 25.7678695,
#                                  'longitude': -80.2143218},
#                  'display_phone': '(786) 452-0161',
#                  'distance': 7577.771231291151,
#                  'id': 'zGf5kkYEU01NQ04DRYVPNQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_2JlPZSpBuU7w3bLiW4HWQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '541 SW 12th Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['541 SW 12th Ave',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Doce Provisions',
#                  'phone': '+17864520161',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 618,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/doce-provisions-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'islas-canarias-restaurant-miami',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'spanish', 'title': 'Spanish'}],
#                  'coordinates': {'latitude': 25.744020150637,
#                                  'longitude': -80.415998615939},
#                  'display_phone': '(305) 559-6666',
#                  'distance': 12847.762380266568,
#                  'id': '9knp4SfI-5n-7GHpRYSeeQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Rq6nVNwWHDLO7csn52cHw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13697 SW 26th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['13697 SW 26th St',
#                                                   'Miami, FL 33175'],
#                               'state': 'FL',
#                               'zip_code': '33175'},
#                  'name': 'Islas Canarias Restaurant',
#                  'phone': '+13055596666',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 562,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/islas-canarias-restaurant-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'el-exquisito-miami-2',
# ...
#                 {'alias': 'lan-pan-asian-cafe-miami-3',
#                  'categories': [{'alias': 'panasian', 'title': 'Pan Asian'},
#                                 {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 25.6927979,
#                                  'longitude': -80.3039098},
#                  'display_phone': '(305) 661-8141',
#                  'distance': 6858.437566219197,
#                  'id': 'RIlXSnTu5z_e30s8JtXwpA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rl2YwkBcXi4_BW1joP2_4g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8332 S Dixie Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['8332 S Dixie Hwy',
#                                                   'Miami, FL 33143'],
#                               'state': 'FL',
#                               'zip_code': '33143'},
#                  'name': 'Lan Pan Asian Cafe',
#                  'phone': '+13056618141',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 428,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/lan-pan-asian-cafe-miami-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'basilic-vietnamese-grill-north-miami',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#                  'coordinates': {'latitude': 25.9116923379431,
#                                  'longitude': -80.1577875074097},
#                  'display_phone': '(305) 944-0577',
#                  'distance': 21963.61770994028,
#                  'id': 'gPmldaphxhv12TEq8Lb1Hg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PVwJpDnrM5UEH-zaQPhL1g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '14734 Biscayne Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'North Miami',
#                               'country': 'US',
#                               'display_address': ['14734 Biscayne Blvd',
#                                                   'North Miami, FL 33181'],
#                               'state': 'FL',
#                               'zip_code': '33181'},
#                  'name': 'Basilic Vietnamese Grill',
#                  'phone': '+13059440577',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 423,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/basilic-vietnamese-grill-north-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'bali-café-miami-2',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'indonesian', 'title': 'Indonesian'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 25.77545, 'longitude': -80.190207},
#                  'display_phone': '(305) 358-5751',
#                  'distance': 10121.385548753831,
#                  'id': 'hv9LbFn6RXu0Zsd560vOvQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/of3CLbLLOFGFIKjFBEhEFA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '109 NE 2nd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['109 NE 2nd Ave',
#                                                   'Miami, FL 33132'],
#                               'state': 'FL',
#                               'zip_code': '33132'},
#                  'name': 'Bali Café',
#                  'phone': '+13053585751',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 371,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/bali-caf%C3%A9-miami-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'rock-a-bangkok-miami',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 25.6844364179994,
#                                  'longitude': -80.4178750816147},
#                  'display_phone': '(305) 380-0344',
#                  'distance': 15058.701257454542,
#                  'id': '8QWVt0nIXOwAz4srNLBmmQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5xbRXhcP1qP4_RfUbP6jgQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13718 SW 88th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['13718 SW 88th St',
#                                                   'Miami, FL 33186'],
#                               'state': 'FL',
#                               'zip_code': '33186'},
#                  'name': 'Rock A Bangkok',
#                  'phone': '+13053800344',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 342,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/rock-a-bangkok-miami?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'miss-saigon-miami-beach',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 25.7779222306573,
#                                  'longitude': -80.1337324533729},
#                  'display_phone': '(305) 531-4200',
#                  'distance': 15708.273126345814,
#                  'id': 'HWHq4I-DkTQ0GT5Kd4pUZg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tUAGhS2GaQ2gu22pr_8CEw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '710 Washington Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami Beach',
#                               'country': 'US',
#                               'display_address': ['710 Washington Ave',
#                                                   'Miami Beach, FL 33139'],
#                               'state': 'FL',
#                               'zip_code': '33139'},
#                  'name': 'Miss Saigon',
#                  'phone': '+13055314200',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 332,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/miss-saigon-miami-beach?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'green-papaya-miami-lakes',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 25.926807,
#                                  'longitude': -80.308064},
#                  'display_phone': '(305) 826-5216',
#                  'distance': 19456.816110853917,
#                  'id': 'bga6ur52mC9mDX6kHmoZDg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3L8LoJuX-7AQ5gl4kVzcVA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '16893 NW 67th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami Lakes',
#                               'country': 'US',
#                               'display_address': ['16893 NW 67th Ave',
#                                                   'Miami Lakes, FL 33015'],
#                               'state': 'FL',
#                               'zip_code': '33015'},
#                  'name': 'Green Papaya',
#                  'phone': '+13058265216',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 329,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/green-papaya-miami-lakes?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'ohho-noodles-market-coral-gables',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'panasian', 'title': 'Pan Asian'}],
#                  'coordinates': {'latitude': 25.71667, 'longitude': -80.2738},
#                  'display_phone': '(305) 663-5881',
#                  'distance': 4257.307031243155,
#                  'id': 'Yzz_gAcCupmgSIn6KStovw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_w9URenCBSHbfQHcItIa2g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1100 S Dixie Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Coral Gables',
#                               'country': 'US',
#                               'display_address': ['1100 S Dixie Hwy',
#                                                   'Coral Gables, FL 33146'],
#                               'state': 'FL',
#                               'zip_code': '33146'},
#                  'name': 'Ohho Noodles Market',
#                  'phone': '+13056635881',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 296,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ohho-noodles-market-coral-gables?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pho-78-pembroke-pines',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 26.010368,
#                                  'longitude': -80.245443},
#                  'display_phone': '(954) 989-6770',
#                  'distance': 28961.29224266315,
#                  'id': 'IFR86llpQQvBUD6TF4rYiQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1qG60qHmj6c2xaLqCJ9S5w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7849 Pines Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Pembroke Pines',
#                               'country': 'US',
#                               'display_address': ['7849 Pines Blvd',
#                                                   'Pembroke Pines, FL 33024'],
#                               'state': 'FL',
#                               'zip_code': '33024'},
#                  'name': 'Pho 78',
#                  'phone': '+19549896770',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 280,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pho-78-pembroke-pines?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pho-thang-restaurant-palmetto-bay',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 25.6202555010309,
#                                  'longitude': -80.347032174468},
#                  'display_phone': '(786) 293-1118',
#                  'distance': 15873.085318926542,
#                  'id': 'BFtjb3DN-oR398NkZlTHZw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m31FJYUr9gjXjReoHRyv_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9539 SW 160th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Palmetto Bay',
#                               'country': 'US',
#                               'display_address': ['9539 SW 160th St',
#                                                   'Palmetto Bay, FL 33157'],
#                               'state': 'FL',
#                               'zip_code': '33157'},
#                  'name': 'Pho Thang Restaurant',
#                  'phone': '+17862931118',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 278,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pho-thang-restaurant-palmetto-bay?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'miss-saigon-bistro-coral-gables',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 25.7512718439102,
#                                  'longitude': -80.2576891332865},
#                  'display_phone': '(305) 446-8006',
#                  'distance': 3047.792232786228,
#                  'id': '1miHaVZzM6G2SgcAXZ-08g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XvVnL_V6quZUHTXCXn4naA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '148 Giralda Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Coral Gables',
#                               'country': 'US',
#                               'display_address': ['148 Giralda Ave',
#                                                   'Coral Gables, FL 33134'],
#                               'state': 'FL',
#                               'zip_code': '33134'},
#                  'name': 'Miss Saigon Bistro',
#                  'phone': '+13054468006',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 266,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/miss-saigon-bistro-coral-gables?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 25.752753731496888,
#                        'longitude': -80.2880859375}},
#  'total': 133}
# done!

# %%
# Create a Dataframe

restaurants_df= pd.DataFrame({                         
                             "Restaurant": name,
                             "City": city,
                             "Latitude": latitude,
                             "Longitude": longitude,                        
                             "price": price,
                             "rating": rating
                            }) 
#Give format to the summary table 
restaurants_df["Latitude"] = restaurants_df["Latitude"].map("{:.2f}".format)
restaurants_df["Longitude"] = restaurants_df["Longitude"].map("{:,.2f}".format)
     
restaurants_df.head(100)
# Out:
#                                           Restaurant               City  \
# 0                                           Hakkasan        Miami Beach
# 1                              Versailles Restaurant              Miami
# 2                             Fritz & Franz Bierhaus       Coral Gables
# 3   Chef Adrianne's Vineyard Restaurant and Wine Bar              Miami
# 4                       The Field Irish Pub & Eatery    Fort Lauderdale
# 5                             Mandolin Aegean Bistro              Miami
# 6                                       Yardie Spice          Homestead
# 7                          Old Heidelberg Restaurant    Fort Lauderdale
# 8                                      Bombay Darbar              Miami
# 9                                          Bali Café              Miami
# 10                                     Beaker & Gray              Miami
# 11                            Mandolin Aegean Bistro              Miami
# 12                    Perricone's Marketplace & Cafe              Miami
# 13                           SUGARCANE Raw Bar Grill              Miami
# 14                                     Zak The Baker              Miami
# 15                                 FINKA Table & Tap              Miami
# 16                                        Cafe Roval              Miami
# 17                                   Tacos & Tattoos              Miami
# 18                                              Kush              Miami
# 19                                     Bombay Darbar              Miami
# 20                         Old Heidelberg Restaurant    Fort Lauderdale
# 21                                     Zak The Baker              Miami
# 22                           IKEA Sunrise Restaurant            Sunrise
# 23                                 FINKA Table & Tap              Miami
# 24                     Yardbird Southern Table & Bar        Miami Beach
# 25                     Bolívar Restaurant Bar Lounge        Miami Beach
# 26                                               KYU              Miami
# 27                            Mandolin Aegean Bistro              Miami
# 28                                    Chayhana Oasis  Sunny Isles Beach
# 29                                       1-800-Lucky              Miami
#
#    Latitude Longitude price  rating
# 0     25.82    -80.12   $$$     4.0
# 1     25.77    -80.25    $$     4.0
# 2     25.75    -80.26    $$     3.5
# 3     25.66    -80.43   $$$     4.5
# 4     26.06    -80.19    $$     4.0
# 5     25.82    -80.19    $$     4.5
# 6     25.47    -80.48    $$     5.0
# 7     26.09    -80.15    $$     4.0
# 8     25.73    -80.24    $$     4.5
# 9     25.78    -80.19    $$     4.5
# 10    25.80    -80.19    $$     4.5
# 11    25.82    -80.19    $$     4.5
# 12    25.77    -80.20    $$     4.0
# 13    25.81    -80.19   $$$     4.0
# 14    25.80    -80.20    $$     4.0
# 15    25.74    -80.43    $$     4.0
# 16    25.83    -80.19    $$     4.5
# 17    25.67    -80.38    $$     4.0
# 18    25.80    -80.19    $$     4.5
# 19    25.73    -80.24    $$     4.5
# 20    26.09    -80.15    $$     4.0
# 21    25.80    -80.20    $$     4.0
# 22    26.12    -80.33     $     3.5
# 23    25.74    -80.43    $$     4.0
# 24    25.79    -80.14   $$$     4.5
# 25    25.78    -80.13    $$     4.5
# 26    25.80    -80.20   $$$     4.5
# 27    25.82    -80.19    $$     4.5
# 28    25.93    -80.12    $$     4.5
# 29    25.80    -80.20    $$     4.0

# %%
#Save DataFrame as csv file
restaurants_df.to_csv( "restaurants_in_airports.csv")

# %%
#Save DataFrame as csv file
#pd.DataFrame.to_csv(restaurants_df, "restaurants_in _airports.csv")
