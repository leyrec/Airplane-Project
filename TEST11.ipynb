# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
import pprint
import matplotlib.pyplot as plt

# %%
types_df = pd.read_csv("ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# Import API key
gkey="h323GWkBwCy3RkzoJGx19eR-THnde-e6YJ4sAkN-zvZOyPCB35nTwT5EPzgpxzZmnvTkd-bWEPqY8TPyiUlTgiSnRXZI8rj-rJ63QOeUZAvHy5MxB-rvFoRkJ5K9XXYx"

# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc, target_key, target_type):
    params = {
    "location": target_loc, 
    "term": target_key,
    "categories": target_type,    
}
    return params
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
loc = str(input("Where are you located?\n"))

name= []
city=[]
latitude= []
longitude= []
price= []
rating=[]
output=[]


def get_rest(cuisine,loc):
    
    #these are the additional params
    add_params = {"sort_by" : "review_count"}

    #these are the original params
    params = s_params(loc,cuisine,"restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    pprint.pprint(s1_results)
    
    if (s1_results):
        name = s1_results["businesses"][0]["name"]
        city = s1_results["businesses"][0]["location"]["city"]
        latitude = s1_results["businesses"][0]["coordinates"]["latitude"]
        longitude = s1_results["businesses"][0]["coordinates"]["longitude"]
        price = s1_results["businesses"][0]["price"]
        rating=s1_results["businesses"][0]["rating"]
        output = [name,city,latitude,longitude,price, rating] 
    else:
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
    
    #print(f"The closest {cuisine.upper()} restaurant is {name} which has a rating of {rating} and is located at: \n {address} \n")   
    
    return output

#this is a long loop so print wait before starting
print("wait... this might take a few minutes.")

# use iterrows to iterate through pandas dataframe
# optional: use tqdm for progress bar: tqdm(iterator,total)
# like this: for index, row in tqdm(types_df.iterrows(), total=types_df.shape[0]):

for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = str(row['ethnicity'])
   
    try:
        output = get_rest(restr_type, loc)
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])
        
        
    except (KeyError, IndexError):
        output = ["NaN","NaN","NaN","NaN","NaN","NaN","NaN"]
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])

#print done when done        
print("done!")
# Out:
# Where are you located?
# seattle
# wait... this might take a few minutes.
# {'businesses': [{'alias': 'din-tai-fung-seattle',
#                  'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#                                 {'alias': 'shanghainese',
#                                  'title': 'Shanghainese'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 47.66164, 'longitude': -122.29921},
#                  'display_phone': '(206) 525-0958',
#                  'distance': 4842.619248577799,
#                  'id': 'ud5NuBZka9lVZdRlhQDrjQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JDwl3CKKdFaeOqjcZ36jMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2621 NE 46th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['2621 NE 46th St',
#                                                   'Seattle, WA 98105'],
#                               'state': 'WA',
#                               'zip_code': '98105'},
#                  'name': 'Din Tai Fung',
#                  'phone': '+12065250958',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2114,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/din-tai-fung-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'harbor-city-restaurant-seattle',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 47.59821, 'longitude': -122.32339},
#                  'display_phone': '(206) 621-2228',
#                  'distance': 3155.507567452402,
#                  'id': 'OjX2LacSZd_w2Olmx55HJA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GaUSvXGfs9yON34kS9QIkw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '707 S King St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['707 S King St',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Harbor City Restaurant',
#                  'phone': '+12066212228',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1554,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/harbor-city-restaurant-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'jade-garden-seattle',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 47.5985020713873,
#                                  'longitude': -122.323515415192},
#                  'display_phone': '(206) 622-8181',
#                  'distance': 3125.1711177168672,
#                  'id': 'GoWeog3TbHM6SL9dL_AnTA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BKnlM9XP1VUjDVBJIS2RxA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '424 7th Ave S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['424 7th Ave S',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Jade Garden',
#                  'phone': '+12066228181',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1423,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jade-garden-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'din-tai-fung-seattle-14',
#                  'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#                                 {'alias': 'shanghainese',
#                                  'title': 'Shanghainese'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 47.61289, 'longitude': -122.33531},
#                  'display_phone': '(206) 682-9888',
#                  'distance': 1399.1438872560698,
#                  'id': 'ZCtSkAulGzhWd1o0oWbYgQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fKx4S50dSx145q29hgtuIA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '600 Pine St',
#                               'address2': 'Ste 403',
#                               'address3': None,
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['600 Pine St',
#                                                   'Ste 403',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Din Tai Fung',
#                  'phone': '+12066829888',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1339,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/din-tai-fung-seattle-14?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mikes-noodle-house-seattle',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.59859, 'longitude': -122.32482},
#                  'display_phone': '(206) 389-7099',
#                  'distance': 3084.211960034711,
#                  'id': 'ySKMvcI3ImApkkMkSjna9A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OXDzBdLlAK4AyKt4bt6u1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '418 Maynard Ave S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['418 Maynard Ave S',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': "Mike's Noodle House",
#                  'phone': '+12063897099',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 1060,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mikes-noodle-house-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'kau-kau-barbeque-seattle',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 47.59847, 'longitude': -122.32471},
#                  'display_phone': '(206) 682-4006',
#                  'distance': 3094.6179439038815,
#                  'id': 'e8UiD4SOyfyv5PIB5i1EvQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zc9ILEIxwPf8PhVG8SuSBQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '656 S King St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['656 S King St',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Kau Kau Barbeque',
#                  'phone': '+12066824006',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 979,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kau-kau-barbeque-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'chan-seattle-seattle-2',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#                  'coordinates': {'latitude': 47.6098823547363,
#                                  'longitude': -122.341438293457},
#                  'display_phone': '(206) 354-3564',
#                  'distance': 1783.8238301371016,
#                  'id': 'h1Q0Wkx5TUUZeVjJrXTwmQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VmCWBN6xBWySopG0kEzplw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '86 Pine St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['86 Pine St',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Chan Seattle',
#                  'phone': '+12063543564',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 878,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chan-seattle-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dough-zone-dumpling-house-seattle-2',
#                  'categories': [{'alias': 'shanghainese',
#                                  'title': 'Shanghainese'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.59788, 'longitude': -122.32749},
#                  'display_phone': '(206) 285-9999',
#                  'distance': 3120.660721815892,
#                  'id': 'DzLycxXa20wdlYeTcyc5-A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tX5lR5jVME1ERDR7wSgmVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '504 5th Ave S',
#                               'address2': 'Ste 109',
#                               'address3': None,
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['504 5th Ave S',
#                                                   'Ste 109',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Dough Zone Dumpling House',
#                  'phone': '+12062859999',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 867,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/dough-zone-dumpling-house-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'kedai-makan-seattle-4',
#                  'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.6179, 'longitude': -122.32658},
#                  'display_phone': '',
#                  'distance': 1073.0051178890512,
#                  'id': 'rXbU5HJx6mihqazytPTgXA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PMqIAYAknTK01diJEspDOA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1802 Bellevue Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1802 Bellevue Ave',
#                                                   'Seattle, WA 98122'],
#                               'state': 'WA',
#                               'zip_code': '98122'},
#                  'name': 'Kedai Makan',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 834,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kedai-makan-seattle-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mee-sum-pastry-seattle',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 47.6091726957566,
#                                  'longitude': -122.341359799475},
#                  'display_phone': '(206) 682-6780',
#                  'distance': 1858.9551655891842,
#                  'id': 'pjxLWC1XqPGAdPxZupJgBg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/du7lzcATANXwsKcAJqxTSQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1526 Pike Pl',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1526 Pike Pl',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Mee Sum Pastry',
#                  'phone': '+12066826780',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 773,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mee-sum-pastry-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'xian-noodles-seattle-4',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'}],
#                  'coordinates': {'latitude': 47.66815, 'longitude': -122.31319},
#                  'display_phone': '(206) 522-8888',
#                  'distance': 5034.301016772765,
#                  'id': 'NCDpIDp2f-DhPO5sL5Hbdw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MErC-4Z-UX9HItR0LVKx0Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5259 University Way NE',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['5259 University Way NE',
#                                                   'Seattle, WA 98105'],
#                               'state': 'WA',
#                               'zip_code': '98105'},
#                  'name': "Xi'an Noodles",
#                  'phone': '+12065228888',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 767,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/xian-noodles-seattle-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'snappy-dragon-seattle',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 47.693703,
#                                  'longitude': -122.317879},
#                  'display_phone': '(206) 528-5575',
#                  'distance': 7706.78641688684,
#                  'id': 'XPJ3zTaQxnlx1k0IVRfzIw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1qxxdBhDvCbuTN-yefnDng/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8917 Roosevelt Way NE',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['8917 Roosevelt Way NE',
#                                                   'Seattle, WA 98115'],
#                               'state': 'WA',
#                               'zip_code': '98115'},
#                  'name': 'Snappy Dragon',
#                  'phone': '+12065285575',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 757,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/snappy-dragon-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'sichuanese-cuisine-seattle',
#                  'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.5993655520798,
#                                  'longitude': -122.317549573997},
#                  'display_phone': '(206) 720-1690',
#                  'distance': 3194.581888156946,
#                  'id': 'hj9s0BVirRTTS4ZV_DtRtw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UISwsNORDDtxrhlEu4rbpA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1048 S Jackson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1048 S Jackson St',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Sichuanese Cuisine',
#                  'phone': '+12067201690',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 623,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sichuanese-cuisine-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'monsoon-seattle-seattle-4',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 47.62493, 'longitude': -122.3076},
#                  'display_phone': '(206) 325-2111',
#                  'distance': 2086.8807195328136,
#                  'id': 'oOVlLL4bZ-wAeoi_k0OUmg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZQzcunGfkN96uuY92O1LXg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '615 19th Ave E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['615 19th Ave E',
#                                                   'Seattle, WA 98112'],
#                               'state': 'WA',
#                               'zip_code': '98112'},
#                  'name': 'Monsoon Seattle',
#                  'phone': '+12063252111',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 604,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/monsoon-seattle-seattle-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hong-kong-bistro-seattle',
#                  'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'hkcafe',
#                                  'title': 'Hong Kong Style Cafe'}],
#                  'coordinates': {'latitude': 47.59801, 'longitude': -122.32543},
#                  'display_phone': '(206) 682-1922',
#                  'distance': 3132.294798012477,
#                  'id': '9hMjWWnGAheTxLh-F-sURg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vGb56SnVh7fadncL75gLTg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '507 Maynard Ave S',
#                               'address2': 'Ste 511C',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['507 Maynard Ave S',
#                                                   'Ste 511C',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'Hong Kong Bistro',
#                  'phone': '+12066821922',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 568,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hong-kong-bistro-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'king-noodle-seattle',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.5982, 'longitude': -122.32551},
#                  'display_phone': '(206) 748-9168',
#                  'distance': 3111.357562618642,
#                  'id': '0GMUVpxMjRrKk7vJO3EC8w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ms4wmgjnoHN-ymhA-jmIug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '615 S King St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['615 S King St',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'King Noodle',
#                  'phone': '+12067489168',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 563,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/king-noodle-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hue-ky-mi-gia-seattle',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.5990692269986,
#                                  'longitude': -122.316223301189},
#                  'display_phone': '(206) 568-1268',
#                  'distance': 3267.2546917383506,
#                  'id': 'qESIVKVPI-Ubz9FVNNDtiA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BS-BCf672BhG22C8ozi1_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1207 S Jackson St',
#                               'address2': 'Ste 101',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1207 S Jackson St',
#                                                   'Ste 101',
#                                                   'Seattle, WA 98144'],
#                               'state': 'WA',
#                               'zip_code': '98144'},
#                  'name': 'Hue Ky Mi Gia',
#                  'phone': '+12065681268',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 511,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hue-ky-mi-gia-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'bamboo-garden-vegetarian-cuisine-seattle',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'},
#                                 {'alias': 'kosher', 'title': 'Kosher'}],
#                  'coordinates': {'latitude': 47.62559, 'longitude': -122.34941},
#                  'display_phone': '(206) 282-6616',
#                  'distance': 1044.587098965122,
#                  'id': 'nTR86uByVEaC1s7w1KIlDw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yRyCHTBhtSbjEcwlX4uUgw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '364 Roy St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['364 Roy St',
#                                                   'Seattle, WA 98109'],
#                               'state': 'WA',
#                               'zip_code': '98109'},
#                  'name': 'Bamboo Garden Vegetarian Cuisine',
#                  'phone': '+12062826616',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 501,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bamboo-garden-vegetarian-cuisine-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'a-hong-kong-kitchen-seattle',
#                  'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#                                 {'alias': 'hkcafe',
#                                  'title': 'Hong Kong Style Cafe'}],
#                  'coordinates': {'latitude': 47.59854, 'longitude': -122.32652},
#                  'display_phone': '(206) 682-1267',
#                  'distance': 3063.9942704448877,
#                  'id': 'bzX2yVjfPEOBzBnZeWXQKQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/co1ZdgRGvwhOneEC7uBatA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '419 6th Ave S',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['419 6th Ave S',
#                                                   'Seattle, WA 98104'],
#                               'state': 'WA',
#                               'zip_code': '98104'},
#                  'name': 'A + Hong Kong Kitchen',
#                  'phone': '+12066821267',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 496,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/a-hong-kong-kitchen-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'country-dough-seattle',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 47.61018, 'longitude': -122.34274},
#                  'display_phone': '(206) 728-2598',
#                  'distance': 1781.6956299797653,
#                  'id': 'f0Isf3GraqzfCDKmMZ83qQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UPhPj2ySfM5DDsIMQrT9rQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1916 Pike Pl',
#                               'address2': 'Ste 14',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1916 Pike Pl',
#                                                   'Ste 14',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Country Dough',
#                  'phone': '+12067282598',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 405,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/country-dough-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 47.62541904760501,
#                        'longitude': -122.33551025390625}},
#  'total': 872}
# {'businesses': [{'alias': 'paseo-caribbean-food-fremont-seattle-2',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'catering', 'title': 'Caterers'}],
#                  'coordinates': {'latitude': 47.65849, 'longitude': -122.35031},
#                  'display_phone': '(206) 545-7440',
#                  'distance': 3840.1176224610704,
#                  'id': 'Wk9f5Zpnu4T6Vzf6CF5iuA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o5csrmtkMORuMcVBW2dnYg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4225 Fremont Ave N',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['4225 Fremont Ave N',
#                                                   'Seattle, WA 98103'],
#                               'state': 'WA',
#                               'zip_code': '98103'},
#                  'name': 'Paseo Caribbean Food - Fremont',
#                  'phone': '+12065457440',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 4999,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/paseo-caribbean-food-fremont-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'un-bien-seattle',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 47.6816885778588,
#                                  'longitude': -122.37663764418},
#                  'display_phone': '(206) 588-2040',
#                  'distance': 6974.109080080676,
#                  'id': '08M3HVlCtr3xl6hmKOPl1g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1NuqkfzIkjaB_OJuR83How/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7302 15th Ave NW',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['7302 15th Ave NW',
#                                                   'Seattle, WA 98117'],
#                               'state': 'WA',
#                               'zip_code': '98117'},
#                  'name': 'Un Bien',
#                  'phone': '+12065882040',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 970,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/un-bien-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'bahama-breeze-tukwila',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'latin', 'title': 'Latin American'}],
#                  'coordinates': {'latitude': 47.46117, 'longitude': -122.26133},
#                  'display_phone': '(206) 241-4448',
#                  'distance': 19097.633980808452,
#                  'id': 'cW1cmV5vHOHn7RdlSUlMIA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jx8cyGVvNyqXYmON2dxc9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '15700 Southcenter Pkwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Tukwila',
#                               'country': 'US',
#                               'display_address': ['15700 Southcenter Pkwy',
#                                                   'Tukwila, WA 98188'],
#                               'state': 'WA',
#                               'zip_code': '98188'},
#                  'name': 'Bahama Breeze',
#                  'phone': '+12062414448',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 849,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bahama-breeze-tukwila?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'bongos-seattle',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'caribbean', 'title': 'Caribbean'}],
#                  'coordinates': {'latitude': 47.6767449533551,
#                                  'longitude': -122.346925400198},
#                  'display_phone': '(206) 420-8548',
#                  'distance': 5770.871794260582,
#                  'id': 'Gn5erxCRML47GgbGYdxzFA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W_EcX7OwpL-BvarRW5NkrQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6501 Aurora Ave N',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['6501 Aurora Ave N',
#                                                   'Seattle, WA 98103'],
#                               'state': 'WA',
#                               'zip_code': '98103'},
#                  'name': 'Bongos',
#                  'phone': '+12064208548',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 826,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bongos-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'island-soul-rum-bar-and-soul-shack-seattle',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'soulfood', 'title': 'Soul Food'}],
#                  'coordinates': {'latitude': 47.55812, 'longitude': -122.28544},
#                  'display_phone': '(206) 329-1202',
#                  'distance': 8372.147532633484,
#                  'id': 'IsWM7BrvfZgZfZnC22_64w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WlfHsIN-OxlkYwhO7AdgpA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4869 Rainier Ave S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['4869 Rainier Ave S',
#                                                   'Seattle, WA 98118'],
#                               'state': 'WA',
#                               'zip_code': '98118'},
#                  'name': 'Island Soul Rum Bar & Soul Shack',
#                  'phone': '+12063291202',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 805,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/island-soul-rum-bar-and-soul-shack-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'azul-restaurant-and-lounge-mill-creek-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'lounges', 'title': 'Lounges'},
#                                 {'alias': 'caribbean', 'title': 'Caribbean'}],
#                  'coordinates': {'latitude': 47.8610642,
#                                  'longitude': -122.2208587},
#                  'display_phone': '(425) 357-5600',
#                  'distance': 27569.290159976943,
#                  'id': 'Ub9S-Navcp6PcpT7UhHzsw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/juXBofkYdqlBZjxQjQ_1Aw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '15118 Main St',
#                               'address2': 'Ste 100',
#                               'address3': '',
#                               'city': 'Mill Creek',
#                               'country': 'US',
#                               'display_address': ['15118 Main St',
#                                                   'Ste 100',
#                                                   'Mill Creek, WA 98012'],
#                               'state': 'WA',
#                               'zip_code': '98012'},
#                  'name': 'Azul Restaurant & Lounge',
#                  'phone': '+14253575600',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 719,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/azul-restaurant-and-lounge-mill-creek-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mojito-seattle',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'colombian', 'title': 'Colombian'},
#                                 {'alias': 'venezuelan', 'title': 'Venezuelan'}],
#                  'coordinates': {'latitude': 47.68448, 'longitude': -122.31602},
#                  'display_phone': '(206) 525-3162',
#                  'distance': 6717.672676414582,
#                  'id': 'OJlYzcWkdrHhDyzwJi3bIQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rcj-dQ0bcr5chnglusZGUg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7545 Lake City Way NE',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['7545 Lake City Way NE',
#                                                   'Seattle, WA 98115'],
#                               'state': 'WA',
#                               'zip_code': '98115'},
#                  'name': 'Mojito',
#                  'phone': '+12065253162',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 661,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/mojito-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'el-balcon-bremerton-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'salvadoran', 'title': 'Salvadoran'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#                  'coordinates': {'latitude': 47.56557, 'longitude': -122.62671},
#                  'display_phone': '(360) 813-1617',
#                  'distance': 22834.446255272076,
#                  'id': 'aBF05J7WiH6mkGFM1vAynw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gMJaD9GPsVmVVy_zgBDqLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '326 Pacific Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Bremerton',
#                               'country': 'US',
#                               'display_address': ['326 Pacific Ave',
#                                                   'Bremerton, WA 98337'],
#                               'state': 'WA',
#                               'zip_code': '98337'},
#                  'name': 'El Balcon',
#                  'phone': '+13608131617',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 525,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/el-balcon-bremerton-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'rumba-seattle',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 47.6138199,
#                                  'longitude': -122.32858},
#                  'display_phone': '(206) 583-7177',
#                  'distance': 1392.7029545875616,
#                  'id': 'ABZ1gV7OVUW6KMYFTYHm9A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tDHnGg11MN_0aZCnkg2KHQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1112 Pike St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1112 Pike St',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Rumba',
#                  'phone': '+12065837177',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 432,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/rumba-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'el-diablo-coffee-seattle-2',
#                  'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 47.63555, 'longitude': -122.35731},
#                  'display_phone': '(206) 285-0693',
#                  'distance': 1989.0498936225213,
#                  'id': 'G4j9EqGHRg2TdQVD3wE8EA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/64IjuEJkwK2kgidBSCYQCw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1825 Queen Anne Ave N',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1825 Queen Anne Ave N',
#                                                   'Seattle, WA 98109'],
#                               'state': 'WA',
#                               'zip_code': '98109'},
#                  'name': 'El Diablo Coffee',
#                  'phone': '+12062850693',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 415,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/el-diablo-coffee-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
# ...
#                  'distance': 8907.253321677792,
#                  'id': 'UcoJKGo1clPDb3EfPl9CAQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ADCd-OoH0PfuTkz0Ok2Q4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '10414 Holman Rd N',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['10414 Holman Rd N',
#                                                   'Seattle, WA 98133'],
#                               'state': 'WA',
#                               'zip_code': '98133'},
#                  'name': 'Bánh Town',
#                  'phone': '+12062574254',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 519,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/b%C3%A1nh-town-seattle-5?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'rainier-restaurant-seattle',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 47.5452983,
#                                  'longitude': -122.2850226},
#                  'display_phone': '(206) 760-1090',
#                  'distance': 9680.318545896558,
#                  'id': 'ABJb2NI6ty03Ty4gRvEu5w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YCf9KcTb-geacgifKHiJkg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6400 Martin Luther King Jr Way S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['6400 Martin Luther King Jr '
#                                                   'Way S',
#                                                   'Seattle, WA 98118'],
#                               'state': 'WA',
#                               'zip_code': '98118'},
#                  'name': 'Rainier Restaurant',
#                  'phone': '+12067601090',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 519,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/rainier-restaurant-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pho-bac-seattle-15',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.6169506,
#                                  'longitude': -122.3310034},
#                  'display_phone': '(206) 621-8816',
#                  'distance': 1000.3982051584588,
#                  'id': 'jF62Yo7fP4dcnqmajOHddA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rON8OfaF1GePY3kEWqsslQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1809 Minor Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1809 Minor Ave',
#                                                   'Seattle, WA 98101'],
#                               'state': 'WA',
#                               'zip_code': '98101'},
#                  'name': 'Pho Bac',
#                  'phone': '+12066218816',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 516,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/pho-bac-seattle-15?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hue-ky-mi-gia-seattle',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.5990692269986,
#                                  'longitude': -122.316223301189},
#                  'display_phone': '(206) 568-1268',
#                  'distance': 3267.2546917383506,
#                  'id': 'qESIVKVPI-Ubz9FVNNDtiA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BS-BCf672BhG22C8ozi1_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1207 S Jackson St',
#                               'address2': 'Ste 101',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1207 S Jackson St',
#                                                   'Ste 101',
#                                                   'Seattle, WA 98144'],
#                               'state': 'WA',
#                               'zip_code': '98144'},
#                  'name': 'Hue Ky Mi Gia',
#                  'phone': '+12065681268',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 511,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hue-ky-mi-gia-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dong-thap-noodles-seattle',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.599758,
#                                  'longitude': -122.317459},
#                  'display_phone': '(206) 325-1122',
#                  'distance': 3163.444754131529,
#                  'id': 'Rr4KFyLV0kEXLdJqjuyhEA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MhltsSw0DlaK-jjOl8mCBw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '303 12th Ave S',
#                               'address2': 'Ste A',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['303 12th Ave S',
#                                                   'Ste A',
#                                                   'Seattle, WA 98144'],
#                               'state': 'WA',
#                               'zip_code': '98144'},
#                  'name': 'Dong Thap Noodles',
#                  'phone': '+12063251122',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 508,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/dong-thap-noodles-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'thanh-vi-seattle-2',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.65919, 'longitude': -122.31296},
#                  'display_phone': '(206) 633-7867',
#                  'distance': 4118.472051882727,
#                  'id': 'EOoj2h1Brzk1AhqScvIHDA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Se_UbXssEIfWuH3LUvYqsw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4226 University Way NE',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['4226 University Way NE',
#                                                   'Seattle, WA 98105'],
#                               'state': 'WA',
#                               'zip_code': '98105'},
#                  'name': 'Thanh Vi',
#                  'phone': '+12066337867',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 470,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/thanh-vi-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pho-bac-súp-shop-seattle-6',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.599506,
#                                  'longitude': -122.315385},
#                  'display_phone': '(206) 568-0882',
#                  'distance': 3252.437430170678,
#                  'id': 'HHeRpP4mJUnABMR43TqQGQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pnFvcB9MV79Rs846UEpHKQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1240 S Jackson St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['1240 S Jackson St',
#                                                   'Seattle, WA 98144'],
#                               'state': 'WA',
#                               'zip_code': '98144'},
#                  'name': 'Pho Bac Súp Shop',
#                  'phone': '+12065680882',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 464,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pho-bac-s%C3%BAp-shop-seattle-6?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'local-pho-seattle',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 47.6146521760056,
#                                  'longitude': -122.344533008587},
#                  'display_phone': '(206) 441-5995',
#                  'distance': 1375.0127485574856,
#                  'id': 'UO1isVN0lMAJxm-wD-Cskw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5YrX49RmpQm1-JeszdqzFQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2230 3rd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['2230 3rd Ave',
#                                                   'Seattle, WA 98121'],
#                               'state': 'WA',
#                               'zip_code': '98121'},
#                  'name': 'Local Pho',
#                  'phone': '+12064415995',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 456,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/local-pho-seattle?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'meekong-bar-seattle-4',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 47.6167700829394,
#                                  'longitude': -122.346869073808},
#                  'display_phone': '(206) 257-1030',
#                  'distance': 1284.393092690387,
#                  'id': '2wceIVHS2iTwPDs4Brnlfg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U13oSc9bhi_hOba-7N0IXA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2525 4th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['2525 4th Ave',
#                                                   'Seattle, WA 98121'],
#                               'state': 'WA',
#                               'zip_code': '98121'},
#                  'name': 'Meekong Bar',
#                  'phone': '+12062571030',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 418,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/meekong-bar-seattle-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'vinason-pho-and-grill-seattle-2',
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'macarons', 'title': 'Macarons'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 47.61757, 'longitude': -122.33809},
#                  'display_phone': '(206) 682-6886',
#                  'distance': 887.9701532907798,
#                  'id': 'j86IuX53cL6Qo7mhR8t5Rg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B04VCob4xMZNjhpPGD9A7Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2134 Westlake Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Seattle',
#                               'country': 'US',
#                               'display_address': ['2134 Westlake Ave',
#                                                   'Seattle, WA 98121'],
#                               'state': 'WA',
#                               'zip_code': '98121'},
#                  'name': 'Vinason Pho & Grill',
#                  'phone': '+12066826886',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 417,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/vinason-pho-and-grill-seattle-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 47.62541904760501,
#                        'longitude': -122.33551025390625}},
#  'total': 575}
# done!

# %%
# Create a Dataframe

restaurants_df= pd.DataFrame({                         
                             "Restaurant": name,
                             "City": city,
                             "Latitude": latitude,
                             "longitude": longitude,                        
                             "price": price,
                             "rating": rating
                            }) 
#Delete spaces on both sides of the column's name
restaurants_df.columns = restaurants_df.columns.str.replace(' ', '')

#Convert data object as float
restaurants_df["Latitude"]=restaurants_df.Latitude.astype(float) 
restaurants_df["longitude"] = pd.to_numeric(restaurants_df.longitude, errors='coerce')
     
restaurants_df.head()
# Out:
#                        Restaurant     City  Latitude  longitude price  rating
# 0                    Din Tai Fung  Seattle  47.66164 -122.29921    $$     4.0
# 1  Paseo Caribbean Food - Fremont  Seattle  47.65849 -122.35031    $$     4.5
# 2               Piroshky Piroshky  Seattle  47.60991 -122.34231     $     4.5
# 3                   The Pink Door  Seattle  47.61028 -122.34250    $$     4.5
# 4                         Quinn's  Seattle  47.61386 -122.31922    $$     4.0

# %%
#Save DataFrame as csv file
restaurants_df.to_csv( "restaurants_yelp.csv")

# %%
#Read data from csv file
airports_df = pd.read_csv("airport_info.csv")

#Delete spaces on both sides of the column's name
airports_df.columns = airports_df.columns.str.replace(' ', '')

#Display data
airports_df.head()
# Out:
#    ZirportID                                         Name          City  \
# 0          1                               Goroka Airport        Goroka
# 1          2                               Madang Airport        Madang
# 2          3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3          4                               Nadzab Airport        Nadzab
# 4          5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude  longitude  Altidude TimeZone DST  \
# 0  Papua New Guinea  GKA  AYGA     -6.08     145.39      5282       10   U
# 1  Papua New Guinea  MAG  AYMD     -5.21     145.79        20       10   U
# 2  Papua New Guinea  HGU  AYMH     -5.83     144.30      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ     -6.57     146.73       239       10   U
# 4  Papua New Guinea  POM  AYPY     -9.44     147.22       146       10   U
#
#        Databasetimezone TypeofAirport       Source
# 0  Pacific/Port_Moresby       airport  OurAirports
# 1  Pacific/Port_Moresby       airport  OurAirports
# 2  Pacific/Port_Moresby       airport  OurAirports
# 3  Pacific/Port_Moresby       airport  OurAirports
# 4  Pacific/Port_Moresby       airport  OurAirports

# %%
# Combine the data into a single dataset
combined_data = pd.merge(restaurants_df, airports_df, how="outer", on = ["Latitude", "longitude"])


# Display the data table for preview
combined_data
# Out:
#                            Restaurant   City_x   Latitude   longitude price  \
# 0                        Din Tai Fung  Seattle  47.661640 -122.299210    $$
# 1      Paseo Caribbean Food - Fremont  Seattle  47.658490 -122.350310    $$
# 2      Paseo Caribbean Food - Fremont  Seattle  47.658490 -122.350310    $$
# 3                   Piroshky Piroshky  Seattle  47.609910 -122.342310     $
# 4                   Piroshky Piroshky  Seattle  47.609910 -122.342310     $
# 5                   Piroshky Piroshky  Seattle  47.609910 -122.342310     $
# 6                   Piroshky Piroshky  Seattle  47.609910 -122.342310     $
# 7                   Piroshky Piroshky  Seattle  47.609910 -122.342310     $
# 8                       The Pink Door  Seattle  47.610280 -122.342500    $$
# 9                       The Pink Door  Seattle  47.610280 -122.342500    $$
# 10                            Quinn's  Seattle  47.613860 -122.319220    $$
# 11                            Quinn's  Seattle  47.613860 -122.319220    $$
# 12                            Quinn's  Seattle  47.613860 -122.319220    $$
# 13                               Lola  Seattle  47.613252 -122.340061    $$
# 14                               Lola  Seattle  47.613252 -122.340061    $$
# 15                               Lola  Seattle  47.613252 -122.340061    $$
# 16                               Lola  Seattle  47.613252 -122.340061    $$
# 17                     Taste of India  Seattle  47.669083 -122.317484    $$
# 18                     Taste of India  Seattle  47.669083 -122.317484    $$
# 19                        Kedai Makan  Seattle  47.617900 -122.326580    $$
# 20             Japonessa Sushi Cocina  Seattle  47.608090 -122.338990    $$
# 21                 Tat's Delicatessen  Seattle  47.601599 -122.332317    $$
# 22                              Revel  Seattle  47.623939 -122.338732    $$
# 23                       Tacos Chukis  Seattle  47.620570 -122.321262     $
# 24                          Local 360  Seattle  47.613448 -122.346202    $$
# 25                   Tizley's Europub  Poulsbo  47.734737 -122.645897    $$
# 26    Toulouse Petit Kitchen & Lounge  Seattle  47.624851 -122.357127    $$
# 27                               List  Seattle  47.613340 -122.345870    $$
# 28                           Thai Tom  Seattle  47.662455 -122.313271     $
# 29                      Tamarind Tree  Seattle  47.599841 -122.317832    $$
# ...                               ...      ...        ...         ...   ...
# 7698                              NaN      NaN  -3.420000   29.910000   NaN
# 7699                              NaN      NaN  37.800000   -1.130000   NaN
# 7700                              NaN      NaN -11.960000  -61.690000   NaN
# 7701                              NaN      NaN  41.780000  -82.680000   NaN
# 7702                              NaN      NaN -12.420000  -64.250000   NaN
# 7703                              NaN      NaN -36.890000  145.180000   NaN
# 7704                              NaN      NaN   9.350000  -83.710000   NaN
# 7705                              NaN      NaN  40.500000   49.980000   NaN
# 7706                              NaN      NaN  42.450000   26.350000   NaN
# 7707                              NaN      NaN  52.560000   24.880000   NaN
# 7708                              NaN      NaN  25.740000  101.880000   NaN
# 7709                              NaN      NaN  28.070000  112.960000   NaN
# 7710                              NaN      NaN  40.580000  120.700000   NaN
# 7711                              NaN      NaN  35.240000   33.720000   NaN
# 7712                              NaN      NaN  -8.920000   33.270000   NaN
# 7713                              NaN      NaN  46.550000   18.940000   NaN
# 7714                              NaN      NaN  -3.740000  137.030000   NaN
# 7715                              NaN      NaN  13.080000   77.600000   NaN
# 7716                              NaN      NaN  40.940000   72.980000   NaN
# 7717                              NaN      NaN  29.720000   35.010000   NaN
# 7718                              NaN      NaN  23.640000   57.490000   NaN
# 7719                              NaN      NaN   8.610000  124.460000   NaN
# 7720                              NaN      NaN  64.620000   30.690000   NaN
# 7721                              NaN      NaN  46.400000   47.890000   NaN
# 7722                              NaN      NaN  55.610000   36.650000   NaN
# 7723                              NaN      NaN  71.620000   52.480000   NaN
# 7724                              NaN      NaN  51.850000  107.740000   NaN
# 7725                              NaN      NaN  58.630000   31.390000   NaN
# 7726                              NaN      NaN -27.260000  -70.780000   NaN
# 7727                              NaN      NaN  46.880000   35.310000   NaN
#
#       rating  ZirportID                                     Name  \
# 0        4.0        NaN                                      NaN
# 1        4.5        NaN                                      NaN
# 2        4.5        NaN                                      NaN
# 3        4.5        NaN                                      NaN
# 4        4.5        NaN                                      NaN
# 5        4.5        NaN                                      NaN
# 6        4.5        NaN                                      NaN
# 7        4.5        NaN                                      NaN
# 8        4.5        NaN                                      NaN
# 9        4.5        NaN                                      NaN
# 10       4.0        NaN                                      NaN
# 11       4.0        NaN                                      NaN
# 12       4.0        NaN                                      NaN
# 13       4.0        NaN                                      NaN
# 14       4.0        NaN                                      NaN
# 15       4.0        NaN                                      NaN
# 16       4.0        NaN                                      NaN
# 17       4.5        NaN                                      NaN
# 18       4.5        NaN                                      NaN
# 19       4.5        NaN                                      NaN
# 20       4.0        NaN                                      NaN
# 21       4.5        NaN                                      NaN
# 22       3.5        NaN                                      NaN
# 23       4.5        NaN                                      NaN
# 24       4.0        NaN                                      NaN
# 25       4.0        NaN                                      NaN
# 26       4.0        NaN                                      NaN
# 27       4.5        NaN                                      NaN
# 28       3.5        NaN                                      NaN
# 29       4.0        NaN                                      NaN
# ...      ...        ...                                      ...
# 7698     NaN    13821.0                           Gitega Airport
# 7699     NaN    13829.0  RegiÌ?n de Murcia International Airport
# 7700     NaN    13830.0                 Fazenda Kajussol Airport
# 7701     NaN    13880.0                     Pelee Island Airport
# 7702     NaN    13881.0                    Costa Marques Airport
# 7703     NaN    13891.0                        Mangalore Airport
# 7704     NaN    14086.0           San Isidro del General Airport
# 7705     NaN    14087.0                           Zabrat Airport
# 7706     NaN    14088.0                          Bezmer Air Base
# 7707     NaN    14089.0                         Osovtsy Air Base
# 7708     NaN    14090.0                         Yuanmou Air Base
# 7709     NaN    14091.0             Changsha Datuopu Airport/AFB
# 7710     NaN    14092.0                       Xingcheng Air Base
# 7711     NaN    14093.0                        Lefkoniko Airport
# 7712     NaN    14095.0                           Songwe Airport
# 7713     NaN    14096.0                   Kalocsa/FoktÔ Airport
# 7714     NaN    14097.0                   Bilogai-Sugapa Airport
# 7715     NaN    14098.0                         Jakkur Aerodrome
# 7716     NaN    14099.0                       Jalal-Abad Airport
# 7717     NaN    14100.0                            Ramon Airport
# 7718     NaN    14101.0                           Rustaq Airport
# 7719     NaN    14102.0                     Laguindingan Airport
# 7720     NaN    14103.0                      Kostomuksha Airport
# 7721     NaN    14104.0                    Privolzhskiy Air Base
# 7722     NaN    14105.0                         Kubinka Air Base
# 7723     NaN    14106.0                      Rogachyovo Air Base
# 7724     NaN    14107.0                    Ulan-Ude East Airport
# 7725     NaN    14108.0                     Krechevitsy Air Base
# 7726     NaN    14109.0              Desierto de Atacama Airport
# 7727     NaN    14110.0                       Melitopol Air Base
#
#                      City_y      Country IATA  ICAO  Altidude TimeZone  DST  \
# 0                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 1                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 2                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 3                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 4                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 5                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 6                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 7                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 8                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 9                       NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 10                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 11                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 12                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 13                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 14                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 15                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 16                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 17                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 18                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 19                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 20                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 21                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 22                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 23                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 24                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 25                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 26                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 27                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 28                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# 29                      NaN          NaN  NaN   NaN       NaN      NaN  NaN
# ...                     ...          ...  ...   ...       ...      ...  ...
# 7698                 Gitega      Burundi  GID  HBBE    5741.0        2    U
# 7699                 Murcia        Spain  RMU  LEMI     632.0        1    E
# 7700  Alta Floresta D'Oeste       Brazil   \N  SJYD     636.0       -4    S
# 7701                  Pelee       Canada   \N  CYPT     572.0       -5    A
# 7702          COSTA MARQUES       Brazil  CQS  SWCQ     555.0       -4    S
# 7703              Mangalore    Australia   \N  YMNG     467.0       10    O
# 7704             San Isidro   Costa Rica   \N  MRSI    2100.0       -6    N
# 7705                   Baku   Azerbaijan  ZXT  UBTT      36.0       \N   \N
# 7706                 Yambol     Bulgaria  JAM  LBIA     509.0       \N   \N
# 7707                Byaroza      Belarus   \N  UMMO       0.0       \N   \N
# 7708                Yuanmou        China  YUA  ZPYM    3810.0       \N   \N
# 7709               Changsha        China   \N  ZGCS     170.0       \N   \N
# 7710                    NaN        China  XEN  ZYXC      30.0       \N   \N
# 7711             GeÌ¤itkale       Cyprus  GEC  LCGK     146.0       \N   \N
# 7712                  Mbeya     Tanzania  MBI  HTGW    4412.0       \N   \N
# 7713         Kalocsa/FoktÔ      Hungary   \N  LHKA     284.0       \N   \N
# 7714    Sugapa-Papua Island    Indonesia  UGU  WABV    7348.0       \N   \N
# 7715              Bengaluru        India   \N  VOJK    3013.0       \N   \N
# 7716             Jalal-Abad   Kyrgyzstan   \N  UAFJ    2591.0       \N   \N
# 7717                  Eilat       Israel  ETM  LLER     288.0       \N   \N
# 7718            Al Masna'ah         Oman  MNH  OORQ     349.0       \N   \N
# 7719    Cagayan de Oro City  Philippines  CGY  RPMY     190.0       \N   \N
# 7720            Kostomuksha       Russia   \N  ULPM     681.0       \N   \N
# 7721              Astrakhan       Russia   \N  XRAP     -66.0       \N   \N
# 7722                Kubinka       Russia   \N  UUMB     614.0       \N   \N
# 7723                 Belaya       Russia   \N  ULDA     272.0       \N   \N
# 7724               Ulan Ude       Russia   \N  XIUW    1670.0       \N   \N
# 7725               Novgorod       Russia   \N  ULLK      85.0       \N   \N
# 7726                Copiapo        Chile  CPO  SCAT     670.0       \N   \N
# 7727              Melitopol      Ukraine   \N  UKDM       0.0       \N   \N
#
#      Databasetimezone TypeofAirport       Source
# 0                 NaN           NaN          NaN
# 1                 NaN           NaN          NaN
# 2                 NaN           NaN          NaN
# 3                 NaN           NaN          NaN
# 4                 NaN           NaN          NaN
# 5                 NaN           NaN          NaN
# 6                 NaN           NaN          NaN
# 7                 NaN           NaN          NaN
# 8                 NaN           NaN          NaN
# 9                 NaN           NaN          NaN
# 10                NaN           NaN          NaN
# 11                NaN           NaN          NaN
# 12                NaN           NaN          NaN
# 13                NaN           NaN          NaN
# 14                NaN           NaN          NaN
# 15                NaN           NaN          NaN
# 16                NaN           NaN          NaN
# 17                NaN           NaN          NaN
# 18                NaN           NaN          NaN
# 19                NaN           NaN          NaN
# 20                NaN           NaN          NaN
# 21                NaN           NaN          NaN
# 22                NaN           NaN          NaN
# 23                NaN           NaN          NaN
# 24                NaN           NaN          NaN
# 25                NaN           NaN          NaN
# 26                NaN           NaN          NaN
# 27                NaN           NaN          NaN
# 28                NaN           NaN          NaN
# 29                NaN           NaN          NaN
# ...               ...           ...          ...
# 7698               \N       airport  OurAirports
# 7699               \N       airport  OurAirports
# 7700               \N       airport  OurAirports
# 7701               \N       airport  OurAirports
# 7702               \N       airport  OurAirports
# 7703               \N       airport  OurAirports
# 7704               \N       airport  OurAirports
# 7705               \N       airport  OurAirports
# 7706               \N       airport  OurAirports
# 7707               \N       airport  OurAirports
# 7708               \N       airport  OurAirports
# 7709               \N       airport  OurAirports
# 7710               \N       airport  OurAirports
# 7711               \N       airport  OurAirports
# 7712               \N       airport  OurAirports
# 7713               \N       airport  OurAirports
# 7714               \N       airport  OurAirports
# 7715               \N       airport  OurAirports
# 7716               \N       airport  OurAirports
# 7717               \N       airport  OurAirports
# 7718               \N       airport  OurAirports
# 7719               \N       airport  OurAirports
# 7720               \N       airport  OurAirports
# 7721               \N       airport  OurAirports
# 7722               \N       airport  OurAirports
# 7723               \N       airport  OurAirports
# 7724               \N       airport  OurAirports
# 7725               \N       airport  OurAirports
# 7726               \N       airport  OurAirports
# 7727               \N       airport  OurAirports
#
# [7728 rows x 18 columns]

# %%
#Save DataFrame as csv file
pd.DataFrame.to_csv(restaurants_df, "restaurants_in _airports.csv")
