# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
import pprint
import matplotlib.pyplot as plt
from citipy import citipy

# %%
#Read data from csv file
airports_df = pd.read_csv("Airport_Output.csv", usecols = ["Airport Name","City","Airport Address", "Lat", "Lng"])

#Delete spaces on both sides of the column's name
airports_df.columns = airports_df.columns.str.replace(' ', '')

#Display Data
airports_df
# Out:
#                City        Lat         Lng  \
# 0     New York City  40.712775  -74.005973
# 1       Los Angeles  34.052234 -118.243685
# 2           Chicago  41.878114  -87.629798
# 3           Houston  29.760427  -95.369803
# 4      Philadelphia  39.952584  -75.165222
# 5           Phoenix  33.448377 -112.074037
# 6       San Antonio  29.424122  -98.493628
# 7         San Diego  32.715738 -117.161084
# 8            Dallas  32.776664  -96.796988
# 9          San Jose  37.338208 -121.886329
# 10           Austin  30.267153  -97.743061
# 11     Jacksonville  30.332184  -81.655651
# 12    San Francisco  37.774929 -122.419415
# 13     Indianapolis  39.768403  -86.158068
# 14         Columbus  39.961176  -82.998794
# 15       Fort Worth  32.755488  -97.330766
# 16        Charlotte  35.227087  -80.843127
# 17          Seattle  47.606209 -122.332071
# 18           Denver  39.739236 -104.990251
# 19          El Paso  31.761878 -106.485022
# 20          Detroit  42.331427  -83.045754
# 21       Washington  38.907192  -77.036871
# 22           Boston  42.360083  -71.058880
# 23          Memphis  35.149534  -90.048980
# 24        Nashville  36.162664  -86.781602
# 25         Portland  45.523062 -122.676481
# 26    Oklahoma City  35.467560  -97.516428
# 27        Las Vegas  36.169941 -115.139830
# 28        Baltimore  39.290385  -76.612189
# 29       Louisville  38.252665  -85.758456
# ..              ...        ...         ...
# 70           Toledo  41.652805  -83.537867
# 71          Lincoln  40.813616  -96.702596
# 72          Orlando  28.538335  -81.379237
# 73      Chula Vista  32.640054 -117.084196
# 74      Jersey City  40.728157  -74.077642
# 75         Chandler  33.306160 -111.841250
# 76       Fort Wayne  41.079273  -85.139351
# 77          Buffalo  42.886447  -78.878369
# 78           Durham  35.994033  -78.898619
# 79   St. Petersburg  27.767601  -82.640291
# 80           Irvine  33.684567 -117.826505
# 81           Laredo  27.530567  -99.480324
# 82          Lubbock  33.577863 -101.855167
# 83          Madison  43.073052  -89.401230
# 84          Gilbert  33.352826 -111.789027
# 85          Norfolk  36.850769  -76.285873
# 86             Reno  39.529633 -119.813803
# 87    Winston-Salem  36.099860  -80.244216
# 88         Glendale  33.538652 -112.185987
# 89          Hialeah  25.857596  -80.278106
# 90          Garland  32.912624  -96.638883
# 91       Scottsdale  33.494170 -111.926052
# 92           Irving  32.814018  -96.948894
# 93       Chesapeake  36.768209  -76.287493
# 94  North Las Vegas  36.198859 -115.117501
# 95          Fremont  37.548270 -121.988572
# 96      Baton Rouge  30.451468  -91.187147
# 97         Richmond  37.540725  -77.436048
# 98            Boise  43.618710 -116.214607
# 99   San Bernardino  34.108345 -117.289765
#
#                                           AirportName  \
# 0                Newark Liberty International Airport
# 1                   Los Angeles International Airport
# 2                        O'Hare International Airport
# 3                            William P. Hobby Airport
# 4                  Philadelphia International Airport
# 5            Phoenix Sky Harbor International Airport
# 6                   San Antonio International Airport
# 7                     San Diego International Airport
# 8             Dallas/Fort Worth International Airport
# 9                 San Francisco International Airport
# 10             Austin-Bergstrom International Airport
# 11                 Jacksonville International Airport
# 12                San Francisco International Airport
# 13                 Indianapolis International Airport
# 14          John Glenn Columbus International Airport
# 15            Dallas/Fort Worth International Airport
# 16            Charlotte Douglas International Airport
# 17               Seattle-Tacoma International Airport
# 18                       Denver International Airport
# 19                      El Paso International Airport
# 20          Detroit Metropolitan Wayne County Airport
# 21                       Dulles International Airport
# 22                 Boston Logan International Airport
# 23                      Memphis International Airport
# 24                    Nashville International Airport
# 25                     Portland International Airport
# 26                          Will Rogers World Airport
# 27                     McCarran International Airport
# 28  Baltimore/Washington International Thurgood Ma...
# 29                   Louisville International Airport
# ..                                                ...
# 70                             Toledo Express Airport
# 71                                    Lincoln Airport
# 72                      Orlando International Airport
# 73                    San Diego International Airport
# 74               Newark Liberty International Airport
# 75           Phoenix Sky Harbor International Airport
# 76                   Fort Wayne International Airport
# 77              Buffalo Niagara International Airport
# 78               Raleigh-Durham International Airport
# 79                        Tampa International Airport
# 80                   LA/Ontario International Airport
# 81                       Laredo International Airport
# 82        Lubbock Preston Smith International Airport
# 83                       Dane County Regional Airport
# 84           Phoenix Sky Harbor International Airport
# 85                      Norfolk International Airport
# 86                   Reno-Tahoe International Airport
# 87               Piedmont Triad International Airport
# 88           Phoenix Sky Harbor International Airport
# 89                        Miami International Airport
# 90            Dallas/Fort Worth International Airport
# 91           Phoenix Sky Harbor International Airport
# 92            Dallas/Fort Worth International Airport
# 93                      Norfolk International Airport
# 94                     McCarran International Airport
# 95                San Francisco International Airport
# 96                   Baton Rouge Metropolitan Airport
# 97                     Richmond International Airport
# 98                  Eckhart International Airport-1S1
# 99                   LA/Ontario International Airport
#
#                                       AirportAddress
# 0                              3 Brewster Rd, Newark
# 1                           1 World Way, Los Angeles
# 2                        10000 W O'Hare Ave, Chicago
# 3                         7800 Airport Blvd, Houston
# 4                   8000 Essington Ave, Philadelphia
# 5                    3400 E Sky Harbor Blvd, Phoenix
# 6                     9800 Airport Blvd, San Antonio
# 7                        3225 N Harbor Dr, San Diego
# 8                      2400 Aviation Dr, DFW Airport
# 9                                      San Francisco
# 10                    3600 Presidential Blvd, Austin
# 11              2400 Yankee Clipper Dr, Jacksonville
# 12                                     San Francisco
# 13  7800 Col. H. Weir Cook Memorial Dr, Indianapolis
# 14              4600 International Gateway, Columbus
# 15                     2400 Aviation Dr, DFW Airport
# 16              5501 Josh Birmingham Pkwy, Charlotte
# 17                 17801 International Blvd, Seattle
# 18                            8500 Peña Blvd, Denver
# 19                          6701 Convair Rd, El Paso
# 20                                           Detroit
# 21                            1 Saarinen Cir, Dulles
# 22                           1 Harborside Dr, Boston
# 23                       2491 Winchester Rd, Memphis
# 24                          1 Terminal Dr, Nashville
# 25                     7000 NE Airport Way, Portland
# 26                   7100 Terminal Dr, Oklahoma City
# 27                 5757 Wayne Newton Blvd, Las Vegas
# 28                                         Baltimore
# 29                       600 Terminal Dr, Louisville
# ..                                               ...
# 70                    11013 Airport Hwy #11, Swanton
# 71                          2400 W Adams St, Lincoln
# 72                        1 Jeff Fuqua Blvd, Orlando
# 73                       3225 N Harbor Dr, San Diego
# 74                             3 Brewster Rd, Newark
# 75                   3400 E Sky Harbor Blvd, Phoenix
# 76                    3801 W Ferguson Rd, Fort Wayne
# 77                          4200 Genesee St, Buffalo
# 78              2400 John Brantley Blvd, Morrisville
# 79                    4100 George J Bean Pkwy, Tampa
# 80                                           Ontario
# 81                     5210 Bob Bullock Loop, Laredo
# 82                5401 N Martin L King Blvd, Lubbock
# 83                    4000 International Ln, Madison
# 84                   3400 E Sky Harbor Blvd, Phoenix
# 85                         2200 Norview Ave, Norfolk
# 86                             2001 E Plumb Ln, Reno
# 87                 1000 Ted Johnson Pkwy, Greensboro
# 88                   3400 E Sky Harbor Blvd, Phoenix
# 89                           2100 NW 42nd Ave, Miami
# 90                     2400 Aviation Dr, DFW Airport
# 91                   3400 E Sky Harbor Blvd, Phoenix
# 92                     2400 Aviation Dr, DFW Airport
# 93                         2200 Norview Ave, Norfolk
# 94                 5757 Wayne Newton Blvd, Las Vegas
# 95                                     San Francisco
# 96               9430 Jackie Cochran Dr, Baton Rouge
# 97            1 Richard E Byrd Terminal Dr, Richmond
# 98                               County Rd 46, Boise
# 99                                           Ontario
#
# [100 rows x 5 columns]

# %%
types_df = pd.read_csv("cuisine.csv")
types_df
# Out:
#          Cuisine
# 0         Afghan
# 1        African
# 2     Senegalese
# 3          South
# 4       American
# 5       American
# 6     Andalusian
# 7        Arabian
# 8           Arab
# 9      Argentine
# 10      Armenian
# 11         Asian
# 12      Asturian
# 13    Australian
# 14      Austrian
# 15     Baguettes
# 16   Bangladeshi
# 17      Barbeque
# 18        Basque
# 19      Bavarian
# 20          Beer
# 21          Beer
# 22         Beisl
# 23       Belgian
# 24       Flemish
# 25       Bistros
# 26         Black
# 27    Brasseries
# 28     Brazilian
# 29     Brazilian
# ..           ...
# 282      Swedish
# 283        Swiss
# 284       Syrian
# 285     Tabernas
# 286    Taiwanese
# 287        Tapas
# 288  Tapas/Small
# 289       Tavola
# 290      Tex-Mex
# 291         Thai
# 292  Traditional
# 293  Traditional
# 294    Trattorie
# 295      Turkish
# 296         Chee
# 297      Gozleme
# 298     Homemade
# 299     Lahmacun
# 300      Ottoman
# 301      Turkish
# 302    Ukrainian
# 303        Uzbek
# 304        Vegan
# 305   Vegetarian
# 306      Venison
# 307   Vietnamese
# 308      Waffles
# 309          Wok
# 310        Wraps
# 311     Yugoslav
#
# [312 rows x 1 columns]

# %%
# Import API key
gkey="h323GWkBwCy3RkzoJGx19eR-THnde-e6YJ4sAkN-zvZOyPCB35nTwT5EPzgpxzZmnvTkd-bWEPqY8TPyiUlTgiSnRXZI8rj-rJ63QOeUZAvHy5MxB-rvFoRkJ5K9XXYx"

# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc, target_key, target_type):
    params = {
    "location": target_loc, 
    "term": target_key,
    "categories": target_type,    
}
    return params
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
loc = str(input("Where are you located?\n"))

name= []
city=[]
latitude= []
longitude= []
price= []
rating=[]
output=[]


def get_rest(cuisine,loc):
    
    #these are the additional params
    add_params = {"sort_by" : "distance","limit" : 3, "radius" : 1000} 

    #these are the original params
    params = s_params(loc,cuisine,"restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    pprint.pprint(s1_results)
    
    if (s1_results):
        name = s1_results["businesses"][0]["name"]
        city = s1_results["businesses"][0]["location"]["city"]
        latitude = s1_results["businesses"][0]["coordinates"]["latitude"]
        longitude = s1_results["businesses"][0]["coordinates"]["longitude"]
        price = s1_results["businesses"][0]["price"]
        rating=s1_results["businesses"][0]["rating"]
        output = [name,city,latitude,longitude,price, rating] 
    else:
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
    
    #print(f"The closest {cuisine.upper()} restaurant is {name} which has a rating of {rating} and is located at: \n {address} \n")   
    
    return output

#this is a long loop so print wait before starting
print("wait... this might take a few minutes.")

# use iterrows to iterate through pandas dataframe
# optional: use tqdm for progress bar: tqdm(iterator,total)
# like this: for index, row in tqdm(types_df.iterrows(), total=types_df.shape[0]):

for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = str(row['Cuisine'])
   
    try:
        output = get_rest(restr_type, loc)
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])
        
        
    except (KeyError, IndexError):
        output = ["NaN","NaN","NaN","NaN","NaN","NaN","NaN"]
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])

#print done when done        
print("done!")
# Out:
# Where are you located?
# 3 Brewster Rd, Newark
# wait... this might take a few minutes.
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'south-philly-steak-and-fries-newark',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'cheesesteaks',
#                                  'title': 'Cheesesteaks'}],
#                  'coordinates': {'latitude': 40.690474,
#                                  'longitude': -74.176496},
#                  'display_phone': '(973) 622-5243',
#                  'distance': 12.03552589900625,
#                  'id': '8fnZWGyo1LPFkTujsUNCpw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JxHp5vhywigyGVWJTa1cMQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark Liberty International '
#                                           'Airport Ewr',
#                               'address2': '',
#                               'address3': 'Terminal C',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark Liberty '
#                                                   'International Airport Ewr',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'South Philly Steak & Fries',
#                  'phone': '+19736225243',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 25,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/south-philly-steak-and-fries-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'garden-state-diner-newark-6',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.69158, 'longitude': -74.175515},
#                  'display_phone': '(973) 648-6791',
#                  'distance': 160.0210031950969,
#                  'id': 'd8L4vfSxWtSiv1QpiPs2uQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KZ_W417L1DqxVEeBWMYj1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Terminal C',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Garden State Diner',
#                  'phone': '+19736486791',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 165,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/garden-state-diner-newark-6?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'phillips-seafood-newark-3',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 40.686560961354,
#                                  'longitude': -74.1805458068848},
#                  'display_phone': '(973) 242-0600',
#                  'distance': 541.1588652127474,
#                  'id': 'KqVsJIUcNV-IeeKDeZ0zKw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IMMUwBX80puWW9FaCi0K_A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Newark International Airport St',
#                               'address2': '',
#                               'address3': 'Terminal A-3',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['1 Newark International '
#                                                   'Airport St',
#                                                   'Terminal A-3',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Phillips Seafood',
#                  'phone': '+19732420600',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 207,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/phillips-seafood-newark-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 6}
# {'businesses': [{'alias': 'guinness-pub-newark',
#                  'categories': [{'alias': 'irish', 'title': 'Irish'},
#                                 {'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 40.690477, 'longitude': -74.1765},
#                  'display_phone': '',
#                  'distance': 12.0391847263633,
#                  'id': 'UEALYbdlaXdHzGl_k_bSbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pzhfQkRxSkwCAdYtv9UfVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport - '
#                                           'Concourse C',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport - Concourse C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Guinness Pub',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 1.5,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/guinness-pub-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'surf-bar-newark',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 40.690462, 'longitude': -74.17679},
#                  'display_phone': '(866) 508-3558',
#                  'distance': 17.71603648855666,
#                  'id': 't2VszCiZG7QkDrv7zfrvaw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0r6bGSpd50Vp8_9B7aliqQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Concourse C1 Terminal C',
#                               'address3': 'Newark Liberty International '
#                                           'Airport',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Concourse C1 Terminal C',
#                                                   'Newark Liberty '
#                                                   'International Airport',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'SURF Bar',
#                  'phone': '+18665083558',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 66,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/surf-bar-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'chilis-restaurant-newark',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 40.690632,
#                                  'longitude': -74.176768},
#                  'display_phone': '(973) 824-4502',
#                  'distance': 29.726059127929325,
#                  'id': '0X2LQWkbyIrQst0sEn7HyA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GR9Mzuh1LHFR0p5S0yewzQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Brewster Rd',
#                               'address2': 'Terminal B',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['1 Brewster Rd',
#                                                   'Terminal B',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': "Chili's Restaurant",
#                  'phone': '+19738244502',
#                  'rating': 1.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chilis-restaurant-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 26}
# {'businesses': [{'alias': 'guinness-pub-newark',
#                  'categories': [{'alias': 'irish', 'title': 'Irish'},
#                                 {'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 40.690477, 'longitude': -74.1765},
#                  'display_phone': '',
#                  'distance': 12.0391847263633,
#                  'id': 'UEALYbdlaXdHzGl_k_bSbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pzhfQkRxSkwCAdYtv9UfVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport - '
#                                           'Concourse C',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport - Concourse C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Guinness Pub',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 1.5,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/guinness-pub-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'surf-bar-newark',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 40.690462, 'longitude': -74.17679},
#                  'display_phone': '(866) 508-3558',
#                  'distance': 17.71603648855666,
#                  'id': 't2VszCiZG7QkDrv7zfrvaw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0r6bGSpd50Vp8_9B7aliqQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Concourse C1 Terminal C',
#                               'address3': 'Newark Liberty International '
#                                           'Airport',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Concourse C1 Terminal C',
#                                                   'Newark Liberty '
#                                                   'International Airport',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'SURF Bar',
#                  'phone': '+18665083558',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 66,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/surf-bar-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'chilis-restaurant-newark',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 40.690632,
#                                  'longitude': -74.176768},
#                  'display_phone': '(973) 824-4502',
#                  'distance': 29.726059127929325,
#                  'id': '0X2LQWkbyIrQst0sEn7HyA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GR9Mzuh1LHFR0p5S0yewzQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Brewster Rd',
#                               'address2': 'Terminal B',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['1 Brewster Rd',
#                                                   'Terminal B',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': "Chili's Restaurant",
#                  'phone': '+19738244502',
#                  'rating': 1.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chilis-restaurant-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 26}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'hamachi-sushi-newark',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 40.6805953979492,
#                                  'longitude': -74.1798858642578},
#                  'display_phone': '',
#                  'distance': 204.19084959803956,
#                  'id': 'W_kV0lK_eQhJNZcbKIiDbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FIBPpNwGY84qnSadloqVdg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark Liberty International '
#                                           'Airport',
#                               'address2': '',
#                               'address3': 'Continental Airlines, Terminal C',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark Liberty '
#                                                   'International Airport',
#                                                   'Continental Airlines, '
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Hamachi Sushi',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 34,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hamachi-sushi-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'sora-japanese-cuisine-and-sushi-bar-newark',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 40.6886029505553,
#                                  'longitude': -74.1774934530258},
#                  'display_phone': '(973) 242-0547',
#                  'distance': 213.41029814991012,
#                  'id': '5poiPRYLyKFv_yKAXPT1CQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5XZgIuq4rI4ZPsYPqyt_3A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Newark Airport',
#                               'address2': '',
#                               'address3': 'Terminal B',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['1 Newark Airport',
#                                                   'Terminal B',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Sora Japanese Cuisine & Sushi Bar',
#                  'phone': '+19732420547',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 154,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sora-japanese-cuisine-and-sushi-bar-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'aviation-grill-newark',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'lounges', 'title': 'Lounges'}],
#                  'coordinates': {'latitude': 40.6924849624648,
#                                  'longitude': -74.1818127918532},
#                  'display_phone': '',
#                  'distance': 497.18209856772677,
#                  'id': 'GIaAkos69sLQ1zf_Nhjpyw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Vyv05E9SHOJHQ9yAIOCJ9g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Hotel Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['1 Hotel Rd',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Aviation Grill',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 39,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/aviation-grill-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 10}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'notorious-pig-newark',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 40.6950081862042,
#                                  'longitude': -74.1737667561527},
#                  'display_phone': '',
#                  'distance': 565.4683084297947,
#                  'id': 'VR2k_ucuiNUD2X-n4xACMQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9MKu29wdFuce0efzR6QoLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Terminal C1',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal C1',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Notorious Pig',
#                  'phone': '',
#                  'rating': 2.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/notorious-pig-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'tony-romas-newark',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 40.6927142,
#                                  'longitude': -74.1863173},
#                  'display_phone': '(973) 854-0891',
#                  'distance': 568.571410668083,
#                  'id': '45hQYGbLr-wzhOi4iTpWWw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_opCVusLJeKzhJkLzugWaA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Space A12',
#                               'address3': 'Terminal A',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Space A12',
#                                                   'Terminal A',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': "Tony Roma's",
#                  'phone': '+19738540891',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 90,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tony-romas-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'garden-state-diner-newark-6',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.69158, 'longitude': -74.175515},
#                  'display_phone': '(973) 648-6791',
#                  'distance': 160.0210031950969,
#                  'id': 'd8L4vfSxWtSiv1QpiPs2uQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KZ_W417L1DqxVEeBWMYj1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Terminal C',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Garden State Diner',
#                  'phone': '+19736486791',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 165,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/garden-state-diner-newark-6?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 8}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'guinness-pub-newark',
#                  'categories': [{'alias': 'irish', 'title': 'Irish'},
#                                 {'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 40.690477, 'longitude': -74.1765},
#                  'display_phone': '',
#                  'distance': 12.0391847263633,
#                  'id': 'UEALYbdlaXdHzGl_k_bSbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pzhfQkRxSkwCAdYtv9UfVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport - '
#                                           'Concourse C',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport - Concourse C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Guinness Pub',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 1.5,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/guinness-pub-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'the-unusual-times-newark',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'british', 'title': 'British'}],
#                  'coordinates': {'latitude': 40.6903824,
#                                  'longitude': -74.1773732},
#                  'display_phone': '',
#                  'distance': 65.41627934297176,
#                  'id': '1DiNPx_BycnIl5vFvOnpNA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESIglVgW43Ju2q75P4U74A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Gate B53',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Gate B53',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'The Unusual Times',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 101,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-unusual-times-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'c1-prima-newark',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 40.6984367370605,
#                                  'longitude': -74.1698226928711},
#                  'display_phone': '',
#                  'distance': 204.19084959803956,
#                  'id': '5KuyXVj2HOiR904Ji23o6w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iiWJkgdV38iPkRsAH82Gvw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport',
#                               'address2': '',
#                               'address3': 'Gate C84',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport',
#                                                   'Gate C84',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'C1 Prima',
#                  'phone': '',
#                  'price': '$$$',
#                  'rating': 1.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/c1-prima-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 7}
# {'businesses': [{'alias': 'guinness-pub-newark',
#                  'categories': [{'alias': 'irish', 'title': 'Irish'},
#                                 {'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 40.690477, 'longitude': -74.1765},
#                  'display_phone': '',
#                  'distance': 12.0391847263633,
#                  'id': 'UEALYbdlaXdHzGl_k_bSbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pzhfQkRxSkwCAdYtv9UfVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport - '
#                                           'Concourse C',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport - Concourse C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Guinness Pub',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 1.5,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/guinness-pub-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'the-unusual-times-newark',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'british', 'title': 'British'}],
#                  'coordinates': {'latitude': 40.6903824,
#                                  'longitude': -74.1773732},
#                  'display_phone': '',
#                  'distance': 65.41627934297176,
#                  'id': '1DiNPx_BycnIl5vFvOnpNA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESIglVgW43Ju2q75P4U74A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Gate B53',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Gate B53',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'The Unusual Times',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 101,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-unusual-times-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'c1-prima-newark',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 40.6984367370605,
#                                  'longitude': -74.1698226928711},
#                  'display_phone': '',
#                  'distance': 204.19084959803956,
#                  'id': '5KuyXVj2HOiR904Ji23o6w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iiWJkgdV38iPkRsAH82Gvw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport',
#                               'address2': '',
#                               'address3': 'Gate C84',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport',
#                                                   'Gate C84',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'C1 Prima',
#                  'phone': '',
#                  'price': '$$$',
#                  'rating': 1.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/c1-prima-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 7}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'the-unusual-times-newark',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'british', 'title': 'British'}],
#                  'coordinates': {'latitude': 40.6903824,
#                                  'longitude': -74.1773732},
#                  'display_phone': '',
#                  'distance': 65.41627934297176,
#                  'id': '1DiNPx_BycnIl5vFvOnpNA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESIglVgW43Ju2q75P4U74A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Gate B53',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Gate B53',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'The Unusual Times',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 101,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-unusual-times-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'saison-newark-7',
#                  'categories': [{'alias': 'french', 'title': 'French'}],
#                  'coordinates': {'latitude': 40.6970153426826,
#                                  'longitude': -74.1785393577027},
#                  'display_phone': '(866) 508-3558',
#                  'distance': 753.8090999559802,
#                  'id': 'UHlpmHTR6G10rm5m2zaMcA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NFEC2EKRzqKklkVJBJl_SQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark Liberty International '
#                                           'Airport - 3 Brewster Rd',
#                               'address2': 'Terminal C',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark Liberty '
#                                                   'International Airport - 3 '
#                                                   'Brewster Rd',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07132'],
#                               'state': 'NJ',
#                               'zip_code': '07132'},
#                  'name': 'Saison',
#                  'phone': '+18665083558',
#                  'price': '$$$',
#                  'rating': 2.5,
#                  'review_count': 194,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/saison-newark-7?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 2}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'the-unusual-times-newark',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'british', 'title': 'British'}],
#                  'coordinates': {'latitude': 40.6903824,
#                                  'longitude': -74.1773732},
#                  'display_phone': '',
#                  'distance': 65.41627934297176,
#                  'id': '1DiNPx_BycnIl5vFvOnpNA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESIglVgW43Ju2q75P4U74A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Gate B53',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Gate B53',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'The Unusual Times',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 101,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-unusual-times-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mediterranean-bistro-newark',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 40.6884891667884,
#                                  'longitude': -74.177030413985},
#                  'display_phone': '(973) 242-1904',
#                  'distance': 215.36277528034353,
#                  'id': 's_xH8_2eCrn9yWj0IYcO3A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UJj3d8p32shUUYlDa6gFqA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': '',
#                               'address3': 'Gate B61 Terminal B',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Gate B61 Terminal B',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Mediterranean Bistro',
#                  'phone': '+19732421904',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 85,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mediterranean-bistro-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'ruby-tuesdays-newark-2',
#                  'categories': [{'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 40.6863911476264,
#                                  'longitude': -74.1797517161773},
#                  'display_phone': '(908) 289-8307',
#                  'distance': 518.8717409369252,
#                  'id': 'KIOHhedfqf9zYoQ3tKacmA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1pfWI7cMudoHPOc471flkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': '',
#                               'address3': 'Terminal A-19, Gate 39',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal A-19, Gate 39',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Ruby Tuesdays',
#                  'phone': '+19082898307',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 130,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ruby-tuesdays-newark-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 8}
# {'businesses': [{'alias': 'guinness-pub-newark',
#                  'categories': [{'alias': 'irish', 'title': 'Irish'},
#                                 {'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 40.690477, 'longitude': -74.1765},
#                  'display_phone': '',
#                  'distance': 12.0391847263633,
#                  'id': 'UEALYbdlaXdHzGl_k_bSbw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pzhfQkRxSkwCAdYtv9UfVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark International Airport - '
#                                           'Concourse C',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark International '
#                                                   'Airport - Concourse C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
# ...
#                               'display_address': ['Newark International '
#                                                   'Airport',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Vitos Gourmet Deli',
#                  'phone': '',
#                  'rating': 3.0,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/vitos-gourmet-deli-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 48}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'wabi-sabi-gates-c70-99-newark',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'panasian', 'title': 'Pan Asian'},
#                                 {'alias': 'hotdogs', 'title': 'Fast Food'}],
#                  'coordinates': {'latitude': 40.68758, 'longitude': -74.182177},
#                  'display_phone': '',
#                  'distance': 565.2286949681373,
#                  'id': '5R3ICArOKtjmHzS1aoX0Hg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JnCR2_rCOLJxxuxTRJYk8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Wabi Sabi - Gates C70-99',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 54,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/wabi-sabi-gates-c70-99-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'panda-express-newark-5',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'hotdogs', 'title': 'Fast Food'}],
#                  'coordinates': {'latitude': 40.6927142,
#                                  'longitude': -74.1863173},
#                  'display_phone': '',
#                  'distance': 568.571410668083,
#                  'id': 'drFX2DbZPpr0PCes4r9wBA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ty2RcOD23-hYWcryxgtdg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Space B7b',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Space B7b',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Panda Express',
#                  'phone': '',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/panda-express-newark-5?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'manchu-wok-newark-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 40.6874011668973,
#                                  'longitude': -74.1823579300596},
#                  'display_phone': '(973) 504-8400',
#                  'distance': 589.0049211700191,
#                  'id': 'CG9-lNmYhWxfb0y9yd61AA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AgQIjDTAwvd1WoDKrse-cw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': '',
#                               'address3': 'Terminal A',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal A',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Manchu Wok',
#                  'phone': '+19735048400',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 14,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/manchu-wok-newark-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 6}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'wabi-sabi-gates-c70-99-newark',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'panasian', 'title': 'Pan Asian'},
#                                 {'alias': 'hotdogs', 'title': 'Fast Food'}],
#                  'coordinates': {'latitude': 40.68758, 'longitude': -74.182177},
#                  'display_phone': '',
#                  'distance': 565.2286949681373,
#                  'id': '5R3ICArOKtjmHzS1aoX0Hg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JnCR2_rCOLJxxuxTRJYk8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Wabi Sabi - Gates C70-99',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 54,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/wabi-sabi-gates-c70-99-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'little-purse-dumpling-newark-4',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 40.6966034870749,
#                                  'longitude': -74.1759732862305},
#                  'display_phone': '(866) 508-3558',
#                  'distance': 692.0263579834731,
#                  'id': '8jGslaAwBP-pjpYboMZ32g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EiddK4SpIIaRkb5JOAjmyQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Terminal C',
#                               'address3': 'Newark Liberty International '
#                                           'Airport',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal C',
#                                                   'Newark Liberty '
#                                                   'International Airport',
#                                                   'Newark, NJ 07132'],
#                               'state': 'NJ',
#                               'zip_code': '07132'},
#                  'name': 'Little Purse Dumpling',
#                  'phone': '+18665083558',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 331,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/little-purse-dumpling-newark-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 2}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}
# {'businesses': [{'alias': 'garden-state-cafeteria-newark',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.690499,
#                                  'longitude': -74.176487},
#                  'display_phone': '(973) 648-0066',
#                  'distance': 14.600095002268732,
#                  'id': 'cLp17gau3c9UR7GeYkX2rQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V0iSIGLVTqF4Jx__BUU8Pg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Newark Liberty International Level',
#                               'address2': '',
#                               'address3': 'Terminal C, Gate 90, Lower level',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Newark Liberty '
#                                                   'International Level',
#                                                   'Terminal C, Gate 90, Lower '
#                                                   'level',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Garden State Cafeteria',
#                  'phone': '+19736480066',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 13,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/garden-state-cafeteria-newark?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'liberty-diner-newark-2',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.6913440636218,
#                                  'longitude': -74.1766354099977},
#                  'display_phone': '',
#                  'distance': 105.24952841193985,
#                  'id': '2msyDdYBeKqjp-jCqOZLQA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gCoMvg4wfPTygT0iVQAlwQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Terminal B',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['Terminal B',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Liberty Diner',
#                  'phone': '',
#                  'rating': 2.0,
#                  'review_count': 19,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/liberty-diner-newark-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'garden-state-diner-newark-6',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.69158, 'longitude': -74.175515},
#                  'display_phone': '(973) 648-6791',
#                  'distance': 160.0210031950969,
#                  'id': 'd8L4vfSxWtSiv1QpiPs2uQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KZ_W417L1DqxVEeBWMYj1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3 Brewster Rd',
#                               'address2': 'Terminal C',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['3 Brewster Rd',
#                                                   'Terminal C',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': 'Garden State Diner',
#                  'phone': '+19736486791',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 165,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/garden-state-diner-newark-6?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 18}
# {'businesses': [],
#  'region': {'center': {'latitude': 40.69039796520161,
#                        'longitude': -74.17659759521484}},
#  'total': 0}

# %%
# Create a Dataframe

restaurants_df= pd.DataFrame({                         
                             "Ethnicity":a
                             "Restaurant": name,
                             "City": city,
                             "Latitude": latitude,
                             "longitude": longitude,                        
                             "price": price,
                             "rating": rating
                            }) 
#Delete spaces on both sides of the column's name
restaurants_df.columns = restaurants_df.columns.str.replace(' ', '')

#Convert data object as float
restaurants_df["Latitude"]=restaurants_df.Latitude.astype(float) 
restaurants_df["longitude"] = pd.to_numeric(restaurants_df.longitude, errors='coerce')

#Give format to the summary table 
#restaurants_df["Latitude"] = restaurants_df["Latitude"].map("{:.2f}".format)
#restaurants_df["longitude"] = restaurants_df["longitude"].map("{:,.2f}".format)
     
restaurants_df.head()

# %%
#Save DataFrame as csv file
restaurants_df.to_csv( "restaurants_yelp.csv")

# %%
# Combine the data into a single dataset
combined_data = pd.merge(restaurants_df, airports_df, how="outer", on = ["Latitude", "longitude"])

# Display the data table for preview
combined_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9f79bcbe2ebb> in <module>
#       1 # Combine the data into a single dataset
# ----> 2 combined_data = pd.merge(restaurants_df, airports_df, how="outer", on = ["Latitude", "longitude"])
#       3
#       4 # Display the data table for preview
#       5 combined_data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     831                         if rk is not None:
#     832                             right_keys.append(
# --> 833                                 right._get_label_or_level_values(rk))
#     834                         else:
#     835                             # work-around for merge_asof(right_index=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'Latitude'

# %%
#Save DataFrame as csv file
pd.DataFrame.to_csv(restaurants_df, "restaurants_in _airports.csv")
