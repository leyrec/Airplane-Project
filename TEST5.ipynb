# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
import pprint

# %%
types_df = pd.read_csv("ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# Import API key
gkey="h323GWkBwCy3RkzoJGx19eR-THnde-e6YJ4sAkN-zvZOyPCB35nTwT5EPzgpxzZmnvTkd-bWEPqY8TPyiUlTgiSnRXZI8rj-rJ63QOeUZAvHy5MxB-rvFoRkJ5K9XXYx"

# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc, target_key, target_type):
    params = {
    "location": target_loc, 
    "term": target_key,
    "categories": target_type,    
}
    return params
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
loc = str(input("Where are you located?\n"))

name= []
city=[]
latitude= []
longitude= []
price= []
rating=[]
output=[]


def get_rest(cuisine,loc):
    
    #these are the additional params
    add_params = {"sort_by" : "review_count", "radius" : 40000}

    #these are the original params
    params = s_params(loc,cuisine,"restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    pprint.pprint(s1_results)
    
    if (s1_results):
        name = s1_results["businesses"][0]["name"]
        city = s1_results["businesses"][0]["location"]["city"]
        latitude = s1_results["businesses"][0]["coordinates"]["latitude"]
        longitude = s1_results["businesses"][0]["coordinates"]["longitude"]
        price = s1_results["businesses"][0]["price"]
        rating=s1_results["businesses"][0]["rating"]
        output = [name,city,latitude,longitude,price, rating] 
    else:
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
    
    #print(f"The closest {cuisine.upper()} restaurant is {name} which has a rating of {rating} and is located at: \n {address} \n")   
    
    return output

#this is a long loop so print wait before starting
print("wait... this might take a few minutes.")

# use iterrows to iterate through pandas dataframe
# optional: use tqdm for progress bar: tqdm(iterator,total)
# like this: for index, row in tqdm(types_df.iterrows(), total=types_df.shape[0]):

for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = str(row['ethnicity'])
   
    try:
        output = get_rest(restr_type, loc)
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])
        
        
    except (KeyError, IndexError):
        output = ["NaN","NaN","NaN","NaN","NaN","NaN","NaN"]
        name.append(output[0])
        city.append(output[1])
        latitude.append(output[2])
        longitude.append(output[3])
        price.append(output[4])
        rating.append(output[5])

#print done when done        
print("done!")
# Out:
# Where are you located?
# US
# wait... this might take a few minutes.
# {'businesses': [{'alias': 'san-tung-san-francisco-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'chicken_wings',
#                                  'title': 'Chicken Wings'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.763693,
#                                  'longitude': -122.469008},
#                  'display_phone': '(415) 242-0828',
#                  'distance': 2877.9920007894843,
#                  'id': 'M0JTO3oyu6gxh1mfFjU-dA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LTtoZ25m8FX1UV37asnTCw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1031 Irving St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1031 Irving St',
#                                                   'San Francisco, CA 94122'],
#                               'state': 'CA',
#                               'zip_code': '94122'},
#                  'name': 'San Tung',
#                  'phone': '+14152420828',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 6723,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/san-tung-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'the-house-san-francisco',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.79851, 'longitude': -122.40706},
#                  'display_phone': '(415) 986-8612',
#                  'distance': 4911.928931733509,
#                  'id': 'ZoZjbOYR-apY8XvommlNUA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UzrNIkdGTZ1-cXuQDsKUmA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1230 Grant Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1230 Grant Ave',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'The House',
#                  'phone': '+14159868612',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 4745,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/the-house-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'r-and-g-lounge-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 37.7941240989441,
#                                  'longitude': -122.404937406342},
#                  'display_phone': '(415) 982-7877',
#                  'distance': 4617.126365341871,
#                  'id': 'ka1_lat2boQwLMsOCiwGiA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MvC2vshFjeaY8DATKk_ZVA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '631 Kearny St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['631 Kearny St',
#                                                   'San Francisco, CA 94108'],
#                               'state': 'CA',
#                               'zip_code': '94108'},
#                  'name': 'R&G Lounge',
#                  'phone': '+14159827877',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 4391,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/r-and-g-lounge-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'good-mong-kok-bakery-san-francisco',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 37.7954584839809,
#                                  'longitude': -122.408358365012},
#                  'display_phone': '(415) 397-2688',
#                  'distance': 4567.4100400050365,
#                  'id': '-sg6DqQNGyTMt0MHoY7diQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FPkV5W2n5tD1-NYgOfaGYg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1039 Stockton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1039 Stockton St',
#                                                   'San Francisco, CA 94108'],
#                               'state': 'CA',
#                               'zip_code': '94108'},
#                  'name': 'Good Mong Kok Bakery',
#                  'phone': '+14153972688',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 2556,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/good-mong-kok-bakery-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mission-chinese-food-san-francisco-4',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.76119, 'longitude': -122.41949},
#                  'display_phone': '(415) 863-2800',
#                  'distance': 1478.9122965985753,
#                  'id': 'sW7WYYrHEvR8yEYxautAgQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TChtlZL8WzHLSHobH0ol0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2234 Mission St',
#                               'address2': '',
#                               'address3': 'Lung Shan Restaurant',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2234 Mission St',
#                                                   'Lung Shan Restaurant',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Mission Chinese Food',
#                  'phone': '+14158632800',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 2319,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/mission-chinese-food-san-francisco-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hunan-homes-restaurant-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.7964057922363,
#                                  'longitude': -122.405654907227},
#                  'display_phone': '(415) 982-2844',
#                  'distance': 4784.378862826334,
#                  'id': 'cHoNUKltOAJWSmNfsZ1h-w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mF9pWakxcd9CiASGYudeiQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '622 Jackson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['622 Jackson St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': "Hunan Home's Restaurant",
#                  'phone': '+14159822844',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2123,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/hunan-homes-restaurant-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hakkasan-san-francisco-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 37.78771, 'longitude': -122.40385},
#                  'display_phone': '(415) 829-8148',
#                  'distance': 4150.868369530434,
#                  'id': 'dN_v0Lu6xhv0yJcx-M0fpg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IAYaBSgAauRKyk7xEF_bcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Kearny St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1 Kearny St',
#                                                   'San Francisco, CA 94108'],
#                               'state': 'CA',
#                               'zip_code': '94108'},
#                  'name': 'Hakkasan',
#                  'phone': '+14158298148',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1731,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hakkasan-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dumpling-time-san-francisco',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.7697533,
#                                  'longitude': -122.4022546},
#                  'display_phone': '(415) 525-4797',
#                  'distance': 3151.2428912681967,
#                  'id': 'VPXezwmTETrwitrzj9BZPA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LpVJS1JQ5thyPRCT99mMCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11 Division St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['11 Division St',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'Dumpling Time',
#                  'phone': '+14155254797',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1684,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/dumpling-time-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'z-and-y-restaurant-san-francisco-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 37.7960764706099,
#                                  'longitude': -122.406014800072},
#                  'display_phone': '(415) 981-8988',
#                  'distance': 4738.499405962859,
#                  'id': 'GzOumj6_QOeQByuc_0yajQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1T7V2TCov-Wn5Njw-HWL4Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '655 Jackson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['655 Jackson St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'Z & Y Restaurant',
#                  'phone': '+14159818988',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1646,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/z-and-y-restaurant-san-francisco-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'm-y-china-san-francisco-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.784236,
#                                  'longitude': -122.406566},
#                  'display_phone': '(415) 580-3001',
#                  'distance': 3692.0663288571463,
#                  'id': 'TCUfp_AdAQv-g7aD6ktEEQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MfD1on4bCDopxim2NBMNtg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '845 Market St',
#                               'address2': 'Ste 480',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['845 Market St',
#                                                   'Ste 480',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'M.Y. China',
#                  'phone': '+14155803001',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1629,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/m-y-china-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'fang-san-francisco-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.785795,
#                                  'longitude': -122.399874},
#                  'display_phone': '(415) 777-8568',
#                  'distance': 4242.21586452734,
#                  'id': 'q22kIfCuND7shr9vkOmwnQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t-GLlX1V6SieBPD0us_4Ag/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '660 Howard St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['660 Howard St',
#                                                   'San Francisco, CA 94105'],
#                               'state': 'CA',
#                               'zip_code': '94105'},
#                  'name': 'Fang',
#                  'phone': '+14157778568',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1579,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/fang-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'good-luck-dim-sum-san-francisco',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 37.7830772399902,
#                                  'longitude': -122.46720123291},
#                  'display_phone': '(415) 386-3388',
#                  'distance': 3659.3062390592895,
#                  'id': 'o8mLw7SrcTPis4NcvLzsOw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fvlcCminph3RPWunB_U3XA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '736 Clement St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['736 Clement St',
#                                                   'San Francisco, CA 94118'],
#                               'state': 'CA',
#                               'zip_code': '94118'},
#                  'name': 'Good Luck Dim Sum',
#                  'phone': '+14153863388',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 1571,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/good-luck-dim-sum-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dragon-beaux-san-francisco',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'}],
#                  'coordinates': {'latitude': 37.7805, 'longitude': -122.4807},
#                  'display_phone': '(415) 333-8899',
#                  'distance': 4459.049282822134,
#                  'id': 'Su1ay8vJyKsHZKQG_eluaA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fmX3U2vlg_u60aRNVHNIqw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5700 Geary Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['5700 Geary Blvd',
#                                                   'San Francisco, CA 94121'],
#                               'state': 'CA',
#                               'zip_code': '94121'},
#                  'name': 'Dragon Beaux',
#                  'phone': '+14153338899',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1498,
#                  'transactions': ['delivery',
#                                   'pickup',
#                                   'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/dragon-beaux-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dumpling-kitchen-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.7423, 'longitude': -122.48701},
#                  'display_phone': '(415) 682-8938',
#                  'distance': 4904.15624633216,
#                  'id': 'BI40rGhpngLNPacrjWpseQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6y5BHK9dSB2eQro4s27y-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1935 Taraval St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1935 Taraval St',
#                                                   'San Francisco, CA 94116'],
#                               'state': 'CA',
#                               'zip_code': '94116'},
#                  'name': 'Dumpling Kitchen',
#                  'phone': '+14156828938',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1474,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/dumpling-kitchen-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'china-live-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.7977636140901,
#                                  'longitude': -122.407851420238},
#                  'display_phone': '(415) 788-8188',
#                  'distance': 4808.186132300881,
#                  'id': 'XZ1_66Wa4tumkbKfTI2dWA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xK241NDuWmhH31eEg270Hw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '644 Broadway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['644 Broadway',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'China Live',
#                  'phone': '+14157888188',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1119,
#                  'transactions': ['delivery',
#                                   'pickup',
#                                   'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/china-live-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'sam-wo-restaurant-san-francisco-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.7942543029785,
#                                  'longitude': -122.405113220215},
#                  'display_phone': '(415) 989-8898',
#                  'distance': 4618.182214394335,
#                  'id': 'Z_X0WvSmh9DUxBD9xhet9Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DvRtrIbSljZLJ3ulyw9qIg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '713 Clay St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['713 Clay St',
#                                                   'San Francisco, CA 94108'],
#                               'state': 'CA',
#                               'zip_code': '94108'},
#                  'name': 'Sam Wo Restaurant',
#                  'phone': '+14159898898',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 1029,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sam-wo-restaurant-san-francisco-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'house-of-pancakes-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#                  'coordinates': {'latitude': 37.742904,
#                                  'longitude': -122.476349},
#                  'display_phone': '(415) 681-8388',
#                  'distance': 4038.6592544518016,
#                  'id': 'DQy0uYB0kym-s3oZZRxs5Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VCnTMGbTTPCH3nXWM-RqxQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '937 Taraval St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['937 Taraval St',
#                                                   'San Francisco, CA 94116'],
#                               'state': 'CA',
#                               'zip_code': '94116'},
#                  'name': 'House Of Pancakes',
#                  'phone': '+14156818388',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 942,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/house-of-pancakes-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'delicious-dim-sum-san-francisco',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 37.796051,
#                                  'longitude': -122.4076004},
#                  'display_phone': '(415) 781-0721',
#                  'distance': 4662.616211534053,
#                  'id': 'Fo5Wscbb9rwcLuaO-sc2zQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GLbV3ywlJj8WbiIUaYcE8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '752 Jackson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['752 Jackson St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'Delicious Dim Sum',
#                  'phone': '+14157810721',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 940,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/delicious-dim-sum-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hai-ky-noodles-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.7840538024902,
#                                  'longitude': -122.417953491211},
#                  'display_phone': '(415) 771-2577',
#                  'distance': 3044.718892971255,
#                  'id': 'wCf2GGyEOkaSFE0xCYpgOA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3jnij09aARw6gbYaKhg7Zw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '707 Ellis St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['707 Ellis St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Hai Ky Noodles',
#                  'phone': '+14157712577',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 930,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hai-ky-noodles-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hong-kong-clay-pot-restaurant-san-francisco',
#                  'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.79588, 'longitude': -122.40649},
#                  'display_phone': '(415) 989-2638',
#                  'distance': 4696.303488339721,
#                  'id': 'Sg_R67gxg9ALW2wtg13aYQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1tlMhNYzvrG_cI_Et5Z02A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '960 Grant Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['960 Grant Ave',
#                                                   'San Francisco, CA 94108'],
#                               'state': 'CA',
#                               'zip_code': '94108'},
#                  'name': 'Hong Kong Clay Pot Restaurant',
#                  'phone': '+14159892638',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 882,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/hong-kong-clay-pot-restaurant-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 37.76089938976322,
#                        'longitude': -122.43644714355469}},
#  'total': 1100}
# {'businesses': [{'alias': 'la-mar-cebichería-peruana-san-francisco-4',
#                  'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'peruvian', 'title': 'Peruvian'}],
#                  'coordinates': {'latitude': 37.7974182368553,
#                                  'longitude': -122.395129846558},
#                  'display_phone': '(415) 397-8880',
#                  'distance': 5447.477112361181,
#                  'id': 'Qbr2JG96K6d31NqqAUxf9g',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6nhDLr-4ly3IIPFdDwbO0g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Pier 1 1/2 The Embarcadero',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['Pier 1 1/2 The Embarcadero',
#                                                   'San Francisco, CA 94111'],
#                               'state': 'CA',
#                               'zip_code': '94111'},
#                  'name': 'La Mar Cebichería Peruana',
#                  'phone': '+14153978880',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 3655,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/la-mar-cebicher%C3%ADa-peruana-san-francisco-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'cha-cha-cha-san-francisco-4',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'cuban', 'title': 'Cuban'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'}],
#                  'coordinates': {'latitude': 37.7691434,
#                                  'longitude': -122.4520399},
#                  'display_phone': '(415) 386-7670',
#                  'distance': 1648.936701704209,
#                  'id': 'kOYj2sGMZnyC1lU-_Uw5fA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rTRFT63eDRgi59LPQyYXcg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1801 Haight St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1801 Haight St',
#                                                   'San Francisco, CA 94117'],
#                               'state': 'CA',
#                               'zip_code': '94117'},
#                  'name': 'Cha Cha Cha',
#                  'phone': '+14153867670',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3208,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/cha-cha-cha-san-francisco-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'limón-rotisserie-san-francisco-3',
#                  'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 37.7570514,
#                                  'longitude': -122.416461},
#                  'display_phone': '(415) 821-2134',
#                  'distance': 1808.3298970637697,
#                  'id': 'r7RwvYMwxDuK3u26fHbYDA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1001 S Van Ness Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1001 S Van Ness Ave',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Limón Rotisserie',
#                  'phone': '+14158212134',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3147,
#                  'transactions': ['restaurant_reservation', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'coqueta-san-francisco',
#                  'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 37.7984671979957,
#                                  'longitude': -122.396616339684},
#                  'display_phone': '(415) 704-8866',
#                  'distance': 5450.137916644509,
#                  'id': 'xv8dq_jBNfQkHeX2wJGlAg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mk0iWboSkesnrneGqklt9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'The Embarcadero',
#                               'address2': '',
#                               'address3': 'Pier 5',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['The Embarcadero',
#                                                   'Pier 5',
#                                                   'San Francisco, CA 94105'],
#                               'state': 'CA',
#                               'zip_code': '94105'},
#                  'name': 'Coqueta',
#                  'phone': '+14157048866',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 2039,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/coqueta-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'cha-cha-cha-san-francisco',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'caribbean', 'title': 'Caribbean'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 37.7597100560449,
#                                  'longitude': -122.418911883739},
#                  'display_phone': '(415) 824-1502',
#                  'distance': 1547.1578355684599,
#                  'id': 'QH8WwAYdr3NrH2QwHiPjog',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iA89P8XFjZ37DezvBqEX3Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2327 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2327 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Cha Cha Cha',
#                  'phone': '+14158241502',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1940,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/cha-cha-cha-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'lolinda-san-francisco',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'latin', 'title': 'Latin American'}],
#                  'coordinates': {'latitude': 37.756673,
#                                  'longitude': -122.4190868},
#                  'display_phone': '(415) 550-6970',
#                  'distance': 1596.8686518402583,
#                  'id': 'wEpiKz--Z2b1q_FSCCNiow',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M8J3ehcOIRRI8ys1Q0hxtw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2518 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2518 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Lolinda',
#                  'phone': '+14155506970',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1923,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lolinda-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'el-techo-san-francisco',
#                  'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 37.7566307288009,
#                                  'longitude': -122.419098317624},
#                  'display_phone': '(415) 550-6970',
#                  'distance': 1597.2918669009632,
#                  'id': 'HECB3khkUffaD2zWCngLuw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YZZvDAXqRriZ4eWS6KIg1g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2516 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2516 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'El Techo',
#                  'phone': '+14155506970',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1816,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/el-techo-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'picaro-san-francisco',
#                  'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#                                 {'alias': 'basque', 'title': 'Basque'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'}],
#                  'coordinates': {'latitude': 37.76513, 'longitude': -122.42245},
#                  'display_phone': '(415) 431-4089',
#                  'distance': 1309.3084983212734,
#                  'id': 'KRcMsXmeILmC8OXmcXOQgA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6ORGcvXEbaG9RlB9L1Hnug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3120 16th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['3120 16th St',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'Picaro',
#                  'phone': '+14154314089',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1546,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/picaro-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'cholita-linda-oakland',
#                  'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'tacos', 'title': 'Tacos'}],
#                  'coordinates': {'latitude': 37.8364704,
#                                  'longitude': -122.2625152},
#                  'display_phone': '(510) 594-7610',
#                  'distance': 17440.05351796604,
#                  'id': 'UHFjEP5dVn4wqcjt7ByUog',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mtBfmRmsvJ9gEMjCdqYNyQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4923 Telegraph Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Oakland',
#                               'country': 'US',
#                               'display_address': ['4923 Telegraph Ave',
#                                                   'Oakland, CA 94609'],
#                               'state': 'CA',
#                               'zip_code': '94609'},
#                  'name': 'Cholita Linda',
#                  'phone': '+15105947610',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1541,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/cholita-linda-oakland?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pica-pica-arepa-kitchen-san-francisco',
#                  'categories': [{'alias': 'gluten_free',
#                                  'title': 'Gluten-Free'},
#                                 {'alias': 'latin', 'title': 'Latin American'}],
#                  'coordinates': {'latitude': 37.766409,
#                                  'longitude': -122.421714},
#                  'display_phone': '(415) 400-5453',
#                  'distance': 1432.7005415777276,
#                  'id': '_Iupdt0IslH_jU8zkKcWLA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hAWS9IidumamHodFIUikIA/o.jpg',
#                  'is_closed': False,
# ...
#                 {'alias': 'freshroll-vietnamese-rolls-and-bowls-san-francisco',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 37.7839351290841,
#                                  'longitude': -122.403370141983},
#                  'display_phone': '(415) 348-1858',
#                  'distance': 3874.694056368605,
#                  'id': 'l1oXDZh6vE-cYreeAcfRBw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mBcghs-L2NZdDFPhSWBMBQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '157 4th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['157 4th St',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'Freshroll Vietnamese Rolls & Bowls',
#                  'phone': '+14153481858',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1185,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/freshroll-vietnamese-rolls-and-bowls-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'miss-saigon-san-francisco-2',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 37.7807121276855,
#                                  'longitude': -122.408767700195},
#                  'display_phone': '(415) 522-0332',
#                  'distance': 3285.2021370850557,
#                  'id': 'kPRMsrxQhRC4NMX8Mord_A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N2sateAFf32mx6Zj5xsMXw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 6th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['100 6th St',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'Miss SaiGon',
#                  'phone': '+14155220332',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1077,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/miss-saigon-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'cordon-bleu-san-francisco',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.7907203,
#                                  'longitude': -122.4205111},
#                  'display_phone': '(415) 673-5637',
#                  'distance': 3626.40961033682,
#                  'id': 'Di4kb-1tnjP5OKFuV8qbUA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iHr8Ni91i35abjVQ0h2gWg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1574 California St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1574 California St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Cordon Bleu',
#                  'phone': '+14156735637',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 1059,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cordon-bleu-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'hai-ky-noodles-san-francisco',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.7840538024902,
#                                  'longitude': -122.417953491211},
#                  'display_phone': '(415) 771-2577',
#                  'distance': 3044.718892971255,
#                  'id': 'wCf2GGyEOkaSFE0xCYpgOA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3jnij09aARw6gbYaKhg7Zw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '707 Ellis St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['707 Ellis St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Hai Ky Noodles',
#                  'phone': '+14157712577',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 930,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hai-ky-noodles-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'dinosaurs-san-francisco-4',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 37.7644154700871,
#                                  'longitude': -122.431834858528},
#                  'display_phone': '(415) 503-1421',
#                  'distance': 563.2436184175186,
#                  'id': 'yC5ATYRQah7MjeTiRsGcvA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7IYQ1nkmrGJgNhTDEr7M4Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2275 Market St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2275 Market St',
#                                                   'San Francisco, CA 94114'],
#                               'state': 'CA',
#                               'zip_code': '94114'},
#                  'name': 'Dinosaurs',
#                  'phone': '+14155031421',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 886,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/dinosaurs-san-francisco-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'mau-san-francisco',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 37.76223, 'longitude': -122.42134},
#                  'display_phone': '(415) 934-8889',
#                  'distance': 1331.3731404695288,
#                  'id': '_-7VgjSfibitQ1-TBvE0Aw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N76WtmkC08PQ6NLGgW-asQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '665 Valencia St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['665 Valencia St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Mau',
#                  'phone': '+14159348889',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 881,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/mau-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'ben-tre-vietnamese-homestyle-cuisine-millbrae',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'soup', 'title': 'Soup'},
#                                 {'alias': 'chicken_wings',
#                                  'title': 'Chicken Wings'}],
#                  'coordinates': {'latitude': 37.60052, 'longitude': -122.39033},
#                  'display_phone': '(650) 689-5588',
#                  'distance': 18288.258312409882,
#                  'id': 'T2xibSmmNFNcLtKVV6ppkg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mhOZShWP3S4Gd_XQwT5jRg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '219 El Camino Real',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Millbrae',
#                               'country': 'US',
#                               'display_address': ['219 El Camino Real',
#                                                   'Millbrae, CA 94030'],
#                               'state': 'CA',
#                               'zip_code': '94030'},
#                  'name': 'Ben Tre Vietnamese Homestyle Cuisine',
#                  'phone': '+16506895588',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 810,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ben-tre-vietnamese-homestyle-cuisine-millbrae?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'tú-lan-san-francisco-4',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.7818811498491,
#                                  'longitude': -122.410135446503},
#                  'display_phone': '(415) 626-0927',
#                  'distance': 3285.0611131472106,
#                  'id': 'cZ1D-Cb2uyDJXik2nFiN0w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PZ4iz4ynlgQ7NPQyWcP2JA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8 6th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['8 6th St',
#                                                   'San Francisco, CA 94103'],
#                               'state': 'CA',
#                               'zip_code': '94103'},
#                  'name': 'Tú Lan',
#                  'phone': '+14156260927',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 772,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/t%C3%BA-lan-san-francisco-4?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'sunflower-vietnamese-restaurant-san-francisco-2',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 37.76262, 'longitude': -122.39777},
#                  'display_phone': '(415) 861-2336',
#                  'distance': 3409.726789876362,
#                  'id': 'navhLJGog28RbtX8Omkf0Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aH9mo3QQYpXBlTjME_KX-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '288 Connecticut St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['288 Connecticut St',
#                                                   'San Francisco, CA 94107'],
#                               'state': 'CA',
#                               'zip_code': '94107'},
#                  'name': 'Sunflower Vietnamese Restaurant',
#                  'phone': '+14158612336',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 763,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sunflower-vietnamese-restaurant-san-francisco-2?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'},
#                 {'alias': 'pho-2000-san-francisco',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.78388, 'longitude': -122.41787},
#                  'display_phone': '(415) 474-1188',
#                  'distance': 3032.968390626513,
#                  'id': 'bLa9Jm04dPersyUN7LFrvw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2LnTtM7Fnx9tYyV7Rw04WA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '637 Larkin St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['637 Larkin St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Pho 2000',
#                  'phone': '+14154741188',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 761,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pho-2000-san-francisco?adjust_creative=Escs5QjxATWJNmN8XTLvqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Escs5QjxATWJNmN8XTLvqQ'}],
#  'region': {'center': {'latitude': 37.76089938976322,
#                        'longitude': -122.43644714355469}},
#  'total': 863}
# done!

# %%
# Create a Dataframe

restaurants_df= pd.DataFrame({                         
                             "Restaurant": name,
                             "City": city,
                             "Latitude": latitude,
                             "Longitude": longitude,                        
                             "price": price,
                             "rating": rating
                            }) 
#Give format to the summary table 
#restaurants_df["Latitude"] = restaurants_df["Latitude"].map("{:.2f}".format)
#restaurants_df["Longitude"] = restaurants_df["Longitude"].map("{:,.2f}".format)
     
restaurants_df.head()
# Out:
#                   Restaurant           City   Latitude   Longitude price  \
# 0                   San Tung  San Francisco  37.763693 -122.469008    $$
# 1  La Mar Cebichería Peruana  San Francisco  37.797418 -122.395130   $$$
# 2                Suppenküche  San Francisco  37.776260 -122.426392    $$
# 3                 Gary Danko  San Francisco  37.805870 -122.420580  $$$$
# 4                Suppenküche  San Francisco  37.776260 -122.426392    $$
#
#    rating
# 0     4.0
# 1     4.0
# 2     4.0
# 3     4.5
# 4     4.0

# %%
#Save DataFrame as csv file
pd.DataFrame.to_csv(restaurants_df, "restaurants_in _airports.csv")

# %%
#Save DataFrame as csv file
#pd.DataFrame.to_csv(restaurants_df, "restaurants_in _airports.csv")
